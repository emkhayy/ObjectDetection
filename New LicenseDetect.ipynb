# %% [markdown]
# <a href="https://colab.research.google.com/github/emkhayy/ObjectDetection/blob/main/New%20LicenseDetect.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # 0. Setup Paths

# %%
import os

# %%
CUSTOM_MODEL_NAME = 'my_ssd_mobnet' 
PRETRAINED_MODEL_NAME = 'ssd_mobilenet_v2_fpnlite_320x320_coco17_tpu-8'
PRETRAINED_MODEL_URL = 'http://download.tensorflow.org/models/object_detection/tf2/20200711/ssd_mobilenet_v2_fpnlite_320x320_coco17_tpu-8.tar.gz'
TF_RECORD_SCRIPT_NAME = 'generate_tfrecord.py'
LABEL_MAP_NAME = 'label_map.pbtxt'

# %%
paths = {
    'WORKSPACE_PATH': os.path.join('Tensorflow', 'workspace'),
    'SCRIPTS_PATH': os.path.join('Tensorflow','scripts'),
    'APIMODEL_PATH': os.path.join('Tensorflow','models'),
    'ANNOTATION_PATH': os.path.join('Tensorflow', 'workspace','annotations'),
    'IMAGE_PATH': os.path.join('Tensorflow', 'workspace','images'),
    'MODEL_PATH': os.path.join('Tensorflow', 'workspace','models'),
    'PRETRAINED_MODEL_PATH': os.path.join('Tensorflow', 'workspace','pre-trained-models'),
    'CHECKPOINT_PATH': os.path.join('Tensorflow', 'workspace','models',CUSTOM_MODEL_NAME), 
    'OUTPUT_PATH': os.path.join('Tensorflow', 'workspace','models',CUSTOM_MODEL_NAME, 'export'), 
    'TFJS_PATH':os.path.join('Tensorflow', 'workspace','models',CUSTOM_MODEL_NAME, 'tfjsexport'), 
    'TFLITE_PATH':os.path.join('Tensorflow', 'workspace','models',CUSTOM_MODEL_NAME, 'tfliteexport'), 
    'PROTOC_PATH':os.path.join('Tensorflow','protoc')
 }

# %%
files = {
    'PIPELINE_CONFIG':os.path.join('Tensorflow', 'workspace','models', CUSTOM_MODEL_NAME, 'pipeline.config'),
    'TF_RECORD_SCRIPT': os.path.join(paths['SCRIPTS_PATH'], TF_RECORD_SCRIPT_NAME), 
    'LABELMAP': os.path.join(paths['ANNOTATION_PATH'], LABEL_MAP_NAME)
}

# %%
for path in paths.values():
    if not os.path.exists(path):
        if os.name == 'posix':
            # !mkdir -p {path}
        if os.name == 'nt':
            # !mkdir {path}

# %% [markdown]
# # 1. Download TF Models Pretrained Models from Tensorflow Model Zoo and Install TFOD

# %%
# https://www.tensorflow.org/install/source_windows

# %%
if os.name=='nt':
    # !pip install wget
    import wget

# %%
if not os.path.exists(os.path.join(paths['APIMODEL_PATH'], 'research', 'object_detection')):
    # !git clone https://github.com/tensorflow/models {paths['APIMODEL_PATH']}
# Out:
# Cloning into 'Tensorflow/models'...
# remote: Enumerating objects: 84357, done.
# remote: Counting objects: 100% (2265/2265), done.
# remote: Compressing objects: 100% (1346/1346), done.
# remote: Total 84357 (delta 976), reused 2173 (delta 906), pack-reused 82092
# Receiving objects: 100% (84357/84357), 598.89 MiB | 20.89 MiB/s, done.
# Resolving deltas: 100% (59598/59598), done.

# %%
# Install Tensorflow Object Detection 
if os.name=='posix':  
    # !apt-get install protobuf-compiler
    # !cd Tensorflow/models/research && protoc object_detection/protos/*.proto --python_out=. && cp object_detection/packages/tf2/setup.py . && python -m pip install . 
    
if os.name=='nt':
    url="https://github.com/protocolbuffers/protobuf/releases/download/v3.15.6/protoc-3.15.6-win64.zip"
    wget.download(url)
    # !move protoc-3.15.6-win64.zip {paths['PROTOC_PATH']}
    # !cd {paths['PROTOC_PATH']} && tar -xf protoc-3.15.6-win64.zip
    os.environ['PATH'] += os.pathsep + os.path.abspath(os.path.join(paths['PROTOC_PATH'], 'bin'))   
    # !cd Tensorflow/models/research && protoc object_detection/protos/*.proto --python_out=. && copy object_detection\\packages\\tf2\\setup.py setup.py && python setup.py build && python setup.py install
    # !cd Tensorflow/models/research/slim && pip install -e .
# Out:
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# protobuf-compiler is already the newest version (3.6.1.3-2ubuntu5.2).
# 0 upgraded, 0 newly installed, 0 to remove and 23 not upgraded.
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Processing /content/Tensorflow/models/research
#   Preparing metadata (setup.py) ... done
# Collecting avro-python3
#   Downloading avro-python3-1.10.2.tar.gz (38 kB)
#   Preparing metadata (setup.py) ... done
# Collecting apache-beam
#   Downloading apache_beam-2.46.0-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (14.5 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 14.5/14.5 MB 91.4 MB/s eta 0:00:00
# Requirement already satisfied: pillow in /usr/local/lib/python3.9/dist-packages (from object-detection==0.1) (8.4.0)
# Requirement already satisfied: lxml in /usr/local/lib/python3.9/dist-packages (from object-detection==0.1) (4.9.2)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.9/dist-packages (from object-detection==0.1) (3.7.1)
# Requirement already satisfied: Cython in /usr/local/lib/python3.9/dist-packages (from object-detection==0.1) (0.29.33)
# Requirement already satisfied: contextlib2 in /usr/local/lib/python3.9/dist-packages (from object-detection==0.1) (0.6.0.post1)
# Requirement already satisfied: tf-slim in /usr/local/lib/python3.9/dist-packages (from object-detection==0.1) (1.1.0)
# Requirement already satisfied: six in /usr/local/lib/python3.9/dist-packages (from object-detection==0.1) (1.16.0)
# Requirement already satisfied: pycocotools in /usr/local/lib/python3.9/dist-packages (from object-detection==0.1) (2.0.6)
# Collecting lvis
#   Downloading lvis-0.5.3-py3-none-any.whl (14 kB)
# Requirement already satisfied: scipy in /usr/local/lib/python3.9/dist-packages (from object-detection==0.1) (1.10.1)
# Requirement already satisfied: pandas in /usr/local/lib/python3.9/dist-packages (from object-detection==0.1) (1.4.4)
# Collecting tf-models-official>=2.5.1
#   Downloading tf_models_official-2.12.0-py2.py3-none-any.whl (2.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.6/2.6 MB 92.6 MB/s eta 0:00:00
# Collecting tensorflow_io
#   Downloading tensorflow_io-0.32.0-cp39-cp39-manylinux_2_12_x86_64.manylinux2010_x86_64.whl (28.0 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 28.0/28.0 MB 55.9 MB/s eta 0:00:00
# Requirement already satisfied: keras in /usr/local/lib/python3.9/dist-packages (from object-detection==0.1) (2.12.0)
# Collecting pyparsing==2.4.7
#   Downloading pyparsing-2.4.7-py2.py3-none-any.whl (67 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 67.8/67.8 KB 6.1 MB/s eta 0:00:00
# Collecting sacrebleu<=2.2.0
#   Downloading sacrebleu-2.2.0-py3-none-any.whl (116 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 116.6/116.6 KB 15.4 MB/s eta 0:00:00
# Requirement already satisfied: tabulate>=0.8.9 in /usr/local/lib/python3.9/dist-packages (from sacrebleu<=2.2.0->object-detection==0.1) (0.8.10)
# Collecting portalocker
#   Downloading portalocker-2.7.0-py2.py3-none-any.whl (15 kB)
# Requirement already satisfied: regex in /usr/local/lib/python3.9/dist-packages (from sacrebleu<=2.2.0->object-detection==0.1) (2022.10.31)
# Collecting colorama
#   Downloading colorama-0.4.6-py2.py3-none-any.whl (25 kB)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.9/dist-packages (from sacrebleu<=2.2.0->object-detection==0.1) (1.22.4)
# Requirement already satisfied: opencv-python-headless in /usr/local/lib/python3.9/dist-packages (from tf-models-official>=2.5.1->object-detection==0.1) (4.7.0.72)
# Collecting pyyaml<6.0,>=5.1
#   Downloading PyYAML-5.4.1-cp39-cp39-manylinux1_x86_64.whl (630 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 630.1/630.1 KB 30.1 MB/s eta 0:00:00
# Collecting sentencepiece
#   Downloading sentencepiece-0.1.97-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 72.9 MB/s eta 0:00:00
# Collecting seqeval
#   Downloading seqeval-1.2.2.tar.gz (43 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 43.6/43.6 KB 6.3 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: kaggle>=1.3.9 in /usr/local/lib/python3.9/dist-packages (from tf-models-official>=2.5.1->object-detection==0.1) (1.5.13)
# Requirement already satisfied: google-api-python-client>=1.6.7 in /usr/local/lib/python3.9/dist-packages (from tf-models-official>=2.5.1->object-detection==0.1) (2.70.0)
# Requirement already satisfied: psutil>=5.4.3 in /usr/local/lib/python3.9/dist-packages (from tf-models-official>=2.5.1->object-detection==0.1) (5.9.4)
# Requirement already satisfied: tensorflow-hub>=0.6.0 in /usr/local/lib/python3.9/dist-packages (from tf-models-official>=2.5.1->object-detection==0.1) (0.13.0)
# Requirement already satisfied: gin-config in /usr/local/lib/python3.9/dist-packages (from tf-models-official>=2.5.1->object-detection==0.1) (0.5.0)
# Collecting tensorflow-addons
#   Downloading tensorflow_addons-0.19.0-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.1/1.1 MB 67.5 MB/s eta 0:00:00
# Requirement already satisfied: tensorflow-datasets in /usr/local/lib/python3.9/dist-packages (from tf-models-official>=2.5.1->object-detection==0.1) (4.8.3)
# Collecting py-cpuinfo>=3.3.0
#   Downloading py_cpuinfo-9.0.0-py3-none-any.whl (22 kB)
# Collecting tensorflow-model-optimization>=0.4.1
#   Downloading tensorflow_model_optimization-0.7.3-py2.py3-none-any.whl (238 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 238.9/238.9 KB 28.1 MB/s eta 0:00:00
# Collecting tensorflow-text~=2.12.0
#   Downloading tensorflow_text-2.12.0-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (6.0 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.0/6.0 MB 92.8 MB/s eta 0:00:00
# Collecting immutabledict
#   Downloading immutabledict-2.2.3-py3-none-any.whl (4.0 kB)
# Requirement already satisfied: tensorflow~=2.12.0 in /usr/local/lib/python3.9/dist-packages (from tf-models-official>=2.5.1->object-detection==0.1) (2.12.0)
# Requirement already satisfied: oauth2client in /usr/local/lib/python3.9/dist-packages (from tf-models-official>=2.5.1->object-detection==0.1) (4.1.3)
# Requirement already satisfied: python-dateutil>=2.8.1 in /usr/local/lib/python3.9/dist-packages (from pandas->object-detection==0.1) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.9/dist-packages (from pandas->object-detection==0.1) (2022.7.1)
# Requirement already satisfied: absl-py>=0.2.2 in /usr/local/lib/python3.9/dist-packages (from tf-slim->object-detection==0.1) (1.4.0)
# Collecting pymongo<4.0.0,>=3.8.0
#   Downloading pymongo-3.13.0-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (515 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 515.5/515.5 KB 42.8 MB/s eta 0:00:00
# Collecting orjson<4.0
#   Downloading orjson-3.8.9-cp39-cp39-manylinux_2_28_x86_64.whl (144 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 144.1/144.1 KB 14.4 MB/s eta 0:00:00
# Collecting fastavro<2,>=0.23.6
#   Downloading fastavro-1.7.3-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (2.7 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.7/2.7 MB 82.8 MB/s eta 0:00:00
# Collecting zstandard<1,>=0.18.0
#   Downloading zstandard-0.20.0-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (2.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.6/2.6 MB 75.4 MB/s eta 0:00:00
# Requirement already satisfied: typing-extensions>=3.7.0 in /usr/local/lib/python3.9/dist-packages (from apache-beam->object-detection==0.1) (4.5.0)
# Collecting crcmod<2.0,>=1.7
#   Downloading crcmod-1.7.tar.gz (89 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 89.7/89.7 KB 9.5 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: protobuf<4,>3.12.2 in /usr/local/lib/python3.9/dist-packages (from apache-beam->object-detection==0.1) (3.20.3)
# Collecting hdfs<3.0.0,>=2.1.0
#   Downloading hdfs-2.7.0-py3-none-any.whl (34 kB)
# Requirement already satisfied: cloudpickle~=2.2.1 in /usr/local/lib/python3.9/dist-packages (from apache-beam->object-detection==0.1) (2.2.1)
# Requirement already satisfied: proto-plus<2,>=1.7.1 in /usr/local/lib/python3.9/dist-packages (from apache-beam->object-detection==0.1) (1.22.2)
# Requirement already satisfied: requests<3.0.0,>=2.24.0 in /usr/local/lib/python3.9/dist-packages (from apache-beam->object-detection==0.1) (2.27.1)
# Requirement already satisfied: pydot<2,>=1.2.0 in /usr/local/lib/python3.9/dist-packages (from apache-beam->object-detection==0.1) (1.4.2)
# Collecting objsize<0.7.0,>=0.6.1
#   Downloading objsize-0.6.1-py3-none-any.whl (9.3 kB)
# Requirement already satisfied: pyarrow<10.0.0,>=3.0.0 in /usr/local/lib/python3.9/dist-packages (from apache-beam->object-detection==0.1) (9.0.0)
# Requirement already satisfied: httplib2<0.22.0,>=0.8 in /usr/local/lib/python3.9/dist-packages (from apache-beam->object-detection==0.1) (0.21.0)
# Collecting fasteners<1.0,>=0.3
#   Downloading fasteners-0.18-py3-none-any.whl (18 kB)
# Collecting dill<0.3.2,>=0.3.1.1
#   Downloading dill-0.3.1.1.tar.gz (151 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 152.0/152.0 KB 15.8 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: grpcio!=1.48.0,<2,>=1.33.1 in /usr/local/lib/python3.9/dist-packages (from apache-beam->object-detection==0.1) (1.53.0)
# Requirement already satisfied: opencv-python>=4.1.0.25 in /usr/local/lib/python3.9/dist-packages (from lvis->object-detection==0.1) (4.7.0.72)
# Requirement already satisfied: kiwisolver>=1.1.0 in /usr/local/lib/python3.9/dist-packages (from lvis->object-detection==0.1) (1.4.4)
# Requirement already satisfied: cycler>=0.10.0 in /usr/local/lib/python3.9/dist-packages (from lvis->object-detection==0.1) (0.11.0)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.9/dist-packages (from matplotlib->object-detection==0.1) (1.0.7)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.9/dist-packages (from matplotlib->object-detection==0.1) (23.0)
# Requirement already satisfied: importlib-resources>=3.2.0 in /usr/local/lib/python3.9/dist-packages (from matplotlib->object-detection==0.1) (5.12.0)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.9/dist-packages (from matplotlib->object-detection==0.1) (4.39.3)
# Requirement already satisfied: tensorflow-io-gcs-filesystem==0.32.0 in /usr/local/lib/python3.9/dist-packages (from tensorflow_io->object-detection==0.1) (0.32.0)
# Requirement already satisfied: uritemplate<5,>=3.0.1 in /usr/local/lib/python3.9/dist-packages (from google-api-python-client>=1.6.7->tf-models-official>=2.5.1->object-detection==0.1) (4.1.1)
# Requirement already satisfied: google-auth-httplib2>=0.1.0 in /usr/local/lib/python3.9/dist-packages (from google-api-python-client>=1.6.7->tf-models-official>=2.5.1->object-detection==0.1) (0.1.0)
# Requirement already satisfied: google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0dev,>=1.31.5 in /usr/local/lib/python3.9/dist-packages (from google-api-python-client>=1.6.7->tf-models-official>=2.5.1->object-detection==0.1) (2.11.0)
# Requirement already satisfied: google-auth<3.0.0dev,>=1.19.0 in /usr/local/lib/python3.9/dist-packages (from google-api-python-client>=1.6.7->tf-models-official>=2.5.1->object-detection==0.1) (2.17.0)
# Collecting docopt
#   Downloading docopt-0.6.2.tar.gz (25 kB)
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: zipp>=3.1.0 in /usr/local/lib/python3.9/dist-packages (from importlib-resources>=3.2.0->matplotlib->object-detection==0.1) (3.15.0)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.9/dist-packages (from kaggle>=1.3.9->tf-models-official>=2.5.1->object-detection==0.1) (4.65.0)
# Requirement already satisfied: python-slugify in /usr/local/lib/python3.9/dist-packages (from kaggle>=1.3.9->tf-models-official>=2.5.1->object-detection==0.1) (8.0.1)
# Requirement already satisfied: certifi in /usr/local/lib/python3.9/dist-packages (from kaggle>=1.3.9->tf-models-official>=2.5.1->object-detection==0.1) (2022.12.7)
# Requirement already satisfied: urllib3 in /usr/local/lib/python3.9/dist-packages (from kaggle>=1.3.9->tf-models-official>=2.5.1->object-detection==0.1) (1.26.15)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /usr/local/lib/python3.9/dist-packages (from requests<3.0.0,>=2.24.0->apache-beam->object-detection==0.1) (2.0.12)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.9/dist-packages (from requests<3.0.0,>=2.24.0->apache-beam->object-detection==0.1) (3.4)
# Requirement already satisfied: gast<=0.4.0,>=0.2.1 in /usr/local/lib/python3.9/dist-packages (from tensorflow~=2.12.0->tf-models-official>=2.5.1->object-detection==0.1) (0.4.0)
# Requirement already satisfied: tensorboard<2.13,>=2.12 in /usr/local/lib/python3.9/dist-packages (from tensorflow~=2.12.0->tf-models-official>=2.5.1->object-detection==0.1) (2.12.0)
# Requirement already satisfied: opt-einsum>=2.3.2 in /usr/local/lib/python3.9/dist-packages (from tensorflow~=2.12.0->tf-models-official>=2.5.1->object-detection==0.1) (3.3.0)
# Requirement already satisfied: libclang>=13.0.0 in /usr/local/lib/python3.9/dist-packages (from tensorflow~=2.12.0->tf-models-official>=2.5.1->object-detection==0.1) (16.0.0)
# Requirement already satisfied: tensorflow-estimator<2.13,>=2.12.0 in /usr/local/lib/python3.9/dist-packages (from tensorflow~=2.12.0->tf-models-official>=2.5.1->object-detection==0.1) (2.12.0)
# Requirement already satisfied: google-pasta>=0.1.1 in /usr/local/lib/python3.9/dist-packages (from tensorflow~=2.12.0->tf-models-official>=2.5.1->object-detection==0.1) (0.2.0)
# Requirement already satisfied: flatbuffers>=2.0 in /usr/local/lib/python3.9/dist-packages (from tensorflow~=2.12.0->tf-models-official>=2.5.1->object-detection==0.1) (23.3.3)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.9/dist-packages (from tensorflow~=2.12.0->tf-models-official>=2.5.1->object-detection==0.1) (67.6.1)
# Requirement already satisfied: termcolor>=1.1.0 in /usr/local/lib/python3.9/dist-packages (from tensorflow~=2.12.0->tf-models-official>=2.5.1->object-detection==0.1) (2.2.0)
# Requirement already satisfied: wrapt<1.15,>=1.11.0 in /usr/local/lib/python3.9/dist-packages (from tensorflow~=2.12.0->tf-models-official>=2.5.1->object-detection==0.1) (1.14.1)
# Requirement already satisfied: astunparse>=1.6.0 in /usr/local/lib/python3.9/dist-packages (from tensorflow~=2.12.0->tf-models-official>=2.5.1->object-detection==0.1) (1.6.3)
# Requirement already satisfied: h5py>=2.9.0 in /usr/local/lib/python3.9/dist-packages (from tensorflow~=2.12.0->tf-models-official>=2.5.1->object-detection==0.1) (3.8.0)
# Requirement already satisfied: jax>=0.3.15 in /usr/local/lib/python3.9/dist-packages (from tensorflow~=2.12.0->tf-models-official>=2.5.1->object-detection==0.1) (0.4.7)
# Requirement already satisfied: dm-tree~=0.1.1 in /usr/local/lib/python3.9/dist-packages (from tensorflow-model-optimization>=0.4.1->tf-models-official>=2.5.1->object-detection==0.1) (0.1.8)
# Requirement already satisfied: rsa>=3.1.4 in /usr/local/lib/python3.9/dist-packages (from oauth2client->tf-models-official>=2.5.1->object-detection==0.1) (4.9)
# Requirement already satisfied: pyasn1-modules>=0.0.5 in /usr/local/lib/python3.9/dist-packages (from oauth2client->tf-models-official>=2.5.1->object-detection==0.1) (0.2.8)
# Requirement already satisfied: pyasn1>=0.1.7 in /usr/local/lib/python3.9/dist-packages (from oauth2client->tf-models-official>=2.5.1->object-detection==0.1) (0.4.8)
# Requirement already satisfied: scikit-learn>=0.21.3 in /usr/local/lib/python3.9/dist-packages (from seqeval->tf-models-official>=2.5.1->object-detection==0.1) (1.2.2)
# Collecting typeguard>=2.7
#   Downloading typeguard-3.0.2-py3-none-any.whl (30 kB)
# Requirement already satisfied: click in /usr/local/lib/python3.9/dist-packages (from tensorflow-datasets->tf-models-official>=2.5.1->object-detection==0.1) (8.1.3)
# Requirement already satisfied: etils[enp,epath]>=0.9.0 in /usr/local/lib/python3.9/dist-packages (from tensorflow-datasets->tf-models-official>=2.5.1->object-detection==0.1) (1.1.1)
# Requirement already satisfied: tensorflow-metadata in /usr/local/lib/python3.9/dist-packages (from tensorflow-datasets->tf-models-official>=2.5.1->object-detection==0.1) (1.12.0)
# Requirement already satisfied: promise in /usr/local/lib/python3.9/dist-packages (from tensorflow-datasets->tf-models-official>=2.5.1->object-detection==0.1) (2.3)
# Requirement already satisfied: toml in /usr/local/lib/python3.9/dist-packages (from tensorflow-datasets->tf-models-official>=2.5.1->object-detection==0.1) (0.10.2)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in /usr/local/lib/python3.9/dist-packages (from astunparse>=1.6.0->tensorflow~=2.12.0->tf-models-official>=2.5.1->object-detection==0.1) (0.40.0)
# Requirement already satisfied: googleapis-common-protos<2.0dev,>=1.56.2 in /usr/local/lib/python3.9/dist-packages (from google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0dev,>=1.31.5->google-api-python-client>=1.6.7->tf-models-official>=2.5.1->object-detection==0.1) (1.59.0)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in /usr/local/lib/python3.9/dist-packages (from google-auth<3.0.0dev,>=1.19.0->google-api-python-client>=1.6.7->tf-models-official>=2.5.1->object-detection==0.1) (5.3.0)
# Requirement already satisfied: ml-dtypes>=0.0.3 in /usr/local/lib/python3.9/dist-packages (from jax>=0.3.15->tensorflow~=2.12.0->tf-models-official>=2.5.1->object-detection==0.1) (0.0.4)
# Requirement already satisfied: joblib>=1.1.1 in /usr/local/lib/python3.9/dist-packages (from scikit-learn>=0.21.3->seqeval->tf-models-official>=2.5.1->object-detection==0.1) (1.1.1)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.9/dist-packages (from scikit-learn>=0.21.3->seqeval->tf-models-official>=2.5.1->object-detection==0.1) (3.1.0)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in /usr/local/lib/python3.9/dist-packages (from tensorboard<2.13,>=2.12->tensorflow~=2.12.0->tf-models-official>=2.5.1->object-detection==0.1) (0.7.0)
# Requirement already satisfied: markdown>=2.6.8 in /usr/local/lib/python3.9/dist-packages (from tensorboard<2.13,>=2.12->tensorflow~=2.12.0->tf-models-official>=2.5.1->object-detection==0.1) (3.4.3)
# Requirement already satisfied: tensorboard-plugin-wit>=1.6.0 in /usr/local/lib/python3.9/dist-packages (from tensorboard<2.13,>=2.12->tensorflow~=2.12.0->tf-models-official>=2.5.1->object-detection==0.1) (1.8.1)
# Requirement already satisfied: werkzeug>=1.0.1 in /usr/local/lib/python3.9/dist-packages (from tensorboard<2.13,>=2.12->tensorflow~=2.12.0->tf-models-official>=2.5.1->object-detection==0.1) (2.2.3)
# Requirement already satisfied: google-auth-oauthlib<0.5,>=0.4.1 in /usr/local/lib/python3.9/dist-packages (from tensorboard<2.13,>=2.12->tensorflow~=2.12.0->tf-models-official>=2.5.1->object-detection==0.1) (0.4.6)
# Requirement already satisfied: importlib-metadata>=3.6 in /usr/local/lib/python3.9/dist-packages (from typeguard>=2.7->tensorflow-addons->tf-models-official>=2.5.1->object-detection==0.1) (6.1.0)
# Requirement already satisfied: text-unidecode>=1.3 in /usr/local/lib/python3.9/dist-packages (from python-slugify->kaggle>=1.3.9->tf-models-official>=2.5.1->object-detection==0.1) (1.3)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in /usr/local/lib/python3.9/dist-packages (from google-auth-oauthlib<0.5,>=0.4.1->tensorboard<2.13,>=2.12->tensorflow~=2.12.0->tf-models-official>=2.5.1->object-detection==0.1) (1.3.1)
# Requirement already satisfied: MarkupSafe>=2.1.1 in /usr/local/lib/python3.9/dist-packages (from werkzeug>=1.0.1->tensorboard<2.13,>=2.12->tensorflow~=2.12.0->tf-models-official>=2.5.1->object-detection==0.1) (2.1.2)
# Requirement already satisfied: oauthlib>=3.0.0 in /usr/local/lib/python3.9/dist-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<0.5,>=0.4.1->tensorboard<2.13,>=2.12->tensorflow~=2.12.0->tf-models-official>=2.5.1->object-detection==0.1) (3.2.2)
# Building wheels for collected packages: object-detection, avro-python3, crcmod, dill, seqeval, docopt
#   Building wheel for object-detection (setup.py) ... done
#   Created wheel for object-detection: filename=object_detection-0.1-py3-none-any.whl size=1697012 sha256=b58964e331f1abcdbf91f2be0e3938994d0afb656f67afca1ae32a427d50a4f0
#   Stored in directory: /tmp/pip-ephem-wheel-cache-m95ixhxj/wheels/13/dc/b4/ca25040453ba296d853cb0ccf7c827a599f84e993647b41f42
#   Building wheel for avro-python3 (setup.py) ... done
#   Created wheel for avro-python3: filename=avro_python3-1.10.2-py3-none-any.whl size=44008 sha256=46bee079ea7c76d72a0cded198803042ca4b038263f14b93649ef1812f67113b
#   Stored in directory: /root/.cache/pip/wheels/5a/29/4d/510c0e098c49c5e49519f430481a5425e60b8752682d7b1e55
#   Building wheel for crcmod (setup.py) ... done
#   Created wheel for crcmod: filename=crcmod-1.7-cp39-cp39-linux_x86_64.whl size=36922 sha256=9f807b996b7d637586e2738e1605d748bd6dda8da8d3489a048546ad8616ac27
#   Stored in directory: /root/.cache/pip/wheels/4a/6c/a6/ffdd136310039bf226f2707a9a8e6857be7d70a3fc061f6b36
#   Building wheel for dill (setup.py) ... done
#   Created wheel for dill: filename=dill-0.3.1.1-py3-none-any.whl size=78545 sha256=bbe5791fc95fbeee80f6d44220872a1896668919698b1016499b7c2519b701e3
#   Stored in directory: /root/.cache/pip/wheels/4f/0b/ce/75d96dd714b15e51cb66db631183ea3844e0c4a6d19741a149
#   Building wheel for seqeval (setup.py) ... done
#   Created wheel for seqeval: filename=seqeval-1.2.2-py3-none-any.whl size=16180 sha256=5dd5601ed9dfbf035788c54b6c58c03b20e9d7d801e3d21e8e6d76338fea57d3
#   Stored in directory: /root/.cache/pip/wheels/e2/a5/92/2c80d1928733611c2747a9820e1324a6835524d9411510c142
#   Building wheel for docopt (setup.py) ... done
#   Created wheel for docopt: filename=docopt-0.6.2-py2.py3-none-any.whl size=13721 sha256=9ccf93950d1d6e878c19ac67c6ef44439518797726a2a716fc5911f0eba13fdf
#   Stored in directory: /root/.cache/pip/wheels/70/4a/46/1309fc853b8d395e60bafaf1b6df7845bdd82c95fd59dd8d2b
# Successfully built object-detection avro-python3 crcmod dill seqeval docopt
# Installing collected packages: sentencepiece, py-cpuinfo, docopt, crcmod, zstandard, tensorflow-model-optimization, tensorflow_io, pyyaml, pyparsing, pymongo, portalocker, orjson, objsize, immutabledict, fasteners, fastavro, dill, colorama, avro-python3, typeguard, sacrebleu, hdfs, tensorflow-addons, seqeval, lvis, apache-beam, tensorflow-text, tf-models-official, object-detection
#   Attempting uninstall: pyyaml
#     Found existing installation: PyYAML 6.0
#     Uninstalling PyYAML-6.0:
#       Successfully uninstalled PyYAML-6.0
#   Attempting uninstall: pyparsing
#     Found existing installation: pyparsing 3.0.9
#     Uninstalling pyparsing-3.0.9:
#       Successfully uninstalled pyparsing-3.0.9
# Successfully installed apache-beam-2.46.0 avro-python3-1.10.2 colorama-0.4.6 crcmod-1.7 dill-0.3.1.1 docopt-0.6.2 fastavro-1.7.3 fasteners-0.18 hdfs-2.7.0 immutabledict-2.2.3 lvis-0.5.3 object-detection-0.1 objsize-0.6.1 orjson-3.8.9 portalocker-2.7.0 py-cpuinfo-9.0.0 pymongo-3.13.0 pyparsing-2.4.7 pyyaml-5.4.1 sacrebleu-2.2.0 sentencepiece-0.1.97 seqeval-1.2.2 tensorflow-addons-0.19.0 tensorflow-model-optimization-0.7.3 tensorflow-text-2.12.0 tensorflow_io-0.32.0 tf-models-official-2.12.0 typeguard-3.0.2 zstandard-0.20.0

# %%
VERIFICATION_SCRIPT = os.path.join(paths['APIMODEL_PATH'], 'research', 'object_detection', 'builders', 'model_builder_tf2_test.py')
# Verify Installation
# !python {VERIFICATION_SCRIPT}
# Out:
# 2023-04-02 00:51:17.769594: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-04-02 00:51:18.684678: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# /usr/local/lib/python3.9/dist-packages/tensorflow_addons/utils/ensure_tf_install.py:53: UserWarning: Tensorflow Addons supports using Python ops for all Tensorflow versions above or equal to 2.9.0 and strictly below 2.12.0 (nightly versions are not supported).
#  The versions of TensorFlow you are currently using is 2.12.0 and is not supported.
# Some things might work, some things might not.
# If you were to encounter a bug, do not file an issue.
# If you want to make sure you're using a tested and supported configuration, either change the TensorFlow version or the TensorFlow Addons's version.
# You can find the compatibility matrix in TensorFlow Addon's readme:
# https://github.com/tensorflow/addons
#   warnings.warn(
# 2023-04-02 00:51:22.788039: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:996] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-04-02 00:51:23.426442: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:996] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-04-02 00:51:23.426804: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:996] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# Running tests under Python 3.9.16: /usr/bin/python3
# [ RUN      ] ModelBuilderTF2Test.test_create_center_net_deepmac
# 2023-04-02 00:51:23.451798: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:996] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-04-02 00:51:23.452141: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:996] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-04-02 00:51:23.452359: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:996] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-04-02 00:51:27.462237: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:996] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-04-02 00:51:27.462615: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:996] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-04-02 00:51:27.462878: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:996] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-04-02 00:51:27.463067: W tensorflow/core/common_runtime/gpu/gpu_bfc_allocator.cc:47] Overriding orig_value setting because the TF_FORCE_GPU_ALLOW_GROWTH environment variable is set. Original config value was 0.
# 2023-04-02 00:51:27.463119: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1635] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 13678 MB memory:  -> device: 0, name: Tesla T4, pci bus id: 0000:00:04.0, compute capability: 7.5
# WARNING:tensorflow:`tf.keras.layers.experimental.SyncBatchNormalization` endpoint is deprecated and will be removed in a future release. Please use `tf.keras.layers.BatchNormalization` with parameter `synchronized` set to True.
# W0402 00:51:27.575181 140151839905600 batch_normalization.py:1426] `tf.keras.layers.experimental.SyncBatchNormalization` endpoint is deprecated and will be removed in a future release. Please use `tf.keras.layers.BatchNormalization` with parameter `synchronized` set to True.
# WARNING:tensorflow:`tf.keras.layers.experimental.SyncBatchNormalization` endpoint is deprecated and will be removed in a future release. Please use `tf.keras.layers.BatchNormalization` with parameter `synchronized` set to True.
# W0402 00:51:27.597055 140151839905600 batch_normalization.py:1426] `tf.keras.layers.experimental.SyncBatchNormalization` endpoint is deprecated and will be removed in a future release. Please use `tf.keras.layers.BatchNormalization` with parameter `synchronized` set to True.
# WARNING:tensorflow:`tf.keras.layers.experimental.SyncBatchNormalization` endpoint is deprecated and will be removed in a future release. Please use `tf.keras.layers.BatchNormalization` with parameter `synchronized` set to True.
# W0402 00:51:27.610506 140151839905600 batch_normalization.py:1426] `tf.keras.layers.experimental.SyncBatchNormalization` endpoint is deprecated and will be removed in a future release. Please use `tf.keras.layers.BatchNormalization` with parameter `synchronized` set to True.
# WARNING:tensorflow:`tf.keras.layers.experimental.SyncBatchNormalization` endpoint is deprecated and will be removed in a future release. Please use `tf.keras.layers.BatchNormalization` with parameter `synchronized` set to True.
# W0402 00:51:27.615512 140151839905600 batch_normalization.py:1426] `tf.keras.layers.experimental.SyncBatchNormalization` endpoint is deprecated and will be removed in a future release. Please use `tf.keras.layers.BatchNormalization` with parameter `synchronized` set to True.
# WARNING:tensorflow:`tf.keras.layers.experimental.SyncBatchNormalization` endpoint is deprecated and will be removed in a future release. Please use `tf.keras.layers.BatchNormalization` with parameter `synchronized` set to True.
# W0402 00:51:27.641039 140151839905600 batch_normalization.py:1426] `tf.keras.layers.experimental.SyncBatchNormalization` endpoint is deprecated and will be removed in a future release. Please use `tf.keras.layers.BatchNormalization` with parameter `synchronized` set to True.
# WARNING:tensorflow:`tf.keras.layers.experimental.SyncBatchNormalization` endpoint is deprecated and will be removed in a future release. Please use `tf.keras.layers.BatchNormalization` with parameter `synchronized` set to True.
# W0402 00:51:27.651189 140151839905600 batch_normalization.py:1426] `tf.keras.layers.experimental.SyncBatchNormalization` endpoint is deprecated and will be removed in a future release. Please use `tf.keras.layers.BatchNormalization` with parameter `synchronized` set to True.
# WARNING:tensorflow:`tf.keras.layers.experimental.SyncBatchNormalization` endpoint is deprecated and will be removed in a future release. Please use `tf.keras.layers.BatchNormalization` with parameter `synchronized` set to True.
# W0402 00:51:27.662591 140151839905600 batch_normalization.py:1426] `tf.keras.layers.experimental.SyncBatchNormalization` endpoint is deprecated and will be removed in a future release. Please use `tf.keras.layers.BatchNormalization` with parameter `synchronized` set to True.
# WARNING:tensorflow:`tf.keras.layers.experimental.SyncBatchNormalization` endpoint is deprecated and will be removed in a future release. Please use `tf.keras.layers.BatchNormalization` with parameter `synchronized` set to True.
# W0402 00:51:27.670388 140151839905600 batch_normalization.py:1426] `tf.keras.layers.experimental.SyncBatchNormalization` endpoint is deprecated and will be removed in a future release. Please use `tf.keras.layers.BatchNormalization` with parameter `synchronized` set to True.
# WARNING:tensorflow:`tf.keras.layers.experimental.SyncBatchNormalization` endpoint is deprecated and will be removed in a future release. Please use `tf.keras.layers.BatchNormalization` with parameter `synchronized` set to True.
# W0402 00:51:27.687213 140151839905600 batch_normalization.py:1426] `tf.keras.layers.experimental.SyncBatchNormalization` endpoint is deprecated and will be removed in a future release. Please use `tf.keras.layers.BatchNormalization` with parameter `synchronized` set to True.
# WARNING:tensorflow:`tf.keras.layers.experimental.SyncBatchNormalization` endpoint is deprecated and will be removed in a future release. Please use `tf.keras.layers.BatchNormalization` with parameter `synchronized` set to True.
# W0402 00:51:27.692713 140151839905600 batch_normalization.py:1426] `tf.keras.layers.experimental.SyncBatchNormalization` endpoint is deprecated and will be removed in a future release. Please use `tf.keras.layers.BatchNormalization` with parameter `synchronized` set to True.
# WARNING:tensorflow:`tf.keras.layers.experimental.SyncBatchNormalization` endpoint is deprecated and will be removed in a future release. Please use `tf.keras.layers.BatchNormalization` with parameter `synchronized` set to True.
# W0402 00:51:27.702629 140151839905600 batch_normalization.py:1426] `tf.keras.layers.experimental.SyncBatchNormalization` endpoint is deprecated and will be removed in a future release. Please use `tf.keras.layers.BatchNormalization` with parameter `synchronized` set to True.
# WARNING:tensorflow:`tf.keras.layers.experimental.SyncBatchNormalization` endpoint is deprecated and will be removed in a future release. Please use `tf.keras.layers.BatchNormalization` with parameter `synchronized` set to True.
# W0402 00:51:27.713604 140151839905600 batch_normalization.py:1426] `tf.keras.layers.experimental.SyncBatchNormalization` endpoint is deprecated and will be removed in a future release. Please use `tf.keras.layers.BatchNormalization` with parameter `synchronized` set to True.
# WARNING:tensorflow:`tf.keras.layers.experimental.SyncBatchNormalization` endpoint is deprecated and will be removed in a future release. Please use `tf.keras.layers.BatchNormalization` with parameter `synchronized` set to True.
# W0402 00:51:27.720405 140151839905600 batch_normalization.py:1426] `tf.keras.layers.experimental.SyncBatchNormalization` endpoint is deprecated and will be removed in a future release. Please use `tf.keras.layers.BatchNormalization` with parameter `synchronized` set to True.
# WARNING:tensorflow:`tf.keras.layers.experimental.SyncBatchNormalization` endpoint is deprecated and will be removed in a future release. Please use `tf.keras.layers.BatchNormalization` with parameter `synchronized` set to True.
# W0402 00:51:27.731220 140151839905600 batch_normalization.py:1426] `tf.keras.layers.experimental.SyncBatchNormalization` endpoint is deprecated and will be removed in a future release. Please use `tf.keras.layers.BatchNormalization` with parameter `synchronized` set to True.
# WARNING:tensorflow:`tf.keras.layers.experimental.SyncBatchNormalization` endpoint is deprecated and will be removed in a future release. Please use `tf.keras.layers.BatchNormalization` with parameter `synchronized` set to True.
# W0402 00:51:27.738062 140151839905600 batch_normalization.py:1426] `tf.keras.layers.experimental.SyncBatchNormalization` endpoint is deprecated and will be removed in a future release. Please use `tf.keras.layers.BatchNormalization` with parameter `synchronized` set to True.
# WARNING:tensorflow:`tf.keras.layers.experimental.SyncBatchNormalization` endpoint is deprecated and will be removed in a future release. Please use `tf.keras.layers.BatchNormalization` with parameter `synchronized` set to True.
# W0402 00:51:27.749220 140151839905600 batch_normalization.py:1426] `tf.keras.layers.experimental.SyncBatchNormalization` endpoint is deprecated and will be removed in a future release. Please use `tf.keras.layers.BatchNormalization` with parameter `synchronized` set to True.
# WARNING:tensorflow:`tf.keras.layers.experimental.SyncBatchNormalization` endpoint is deprecated and will be removed in a future release. Please use `tf.keras.layers.BatchNormalization` with parameter `synchronized` set to True.
# W0402 00:51:27.755920 140151839905600 batch_normalization.py:1426] `tf.keras.layers.experimental.SyncBatchNormalization` endpoint is deprecated and will be removed in a future release. Please use `tf.keras.layers.BatchNormalization` with parameter `synchronized` set to True.
# WARNING:tensorflow:`tf.keras.layers.experimental.SyncBatchNormalization` endpoint is deprecated and will be removed in a future release. Please use `tf.keras.layers.BatchNormalization` with parameter `synchronized` set to True.
# W0402 00:51:27.769061 140151839905600 batch_normalization.py:1426] `tf.keras.layers.experimental.SyncBatchNormalization` endpoint is deprecated and will be removed in a future release. Please use `tf.keras.layers.BatchNormalization` with parameter `synchronized` set to True.
# WARNING:tensorflow:`tf.keras.layers.experimental.SyncBatchNormalization` endpoint is deprecated and will be removed in a future release. Please use `tf.keras.layers.BatchNormalization` with parameter `synchronized` set to True.
# W0402 00:51:27.772844 140151839905600 batch_normalization.py:1426] `tf.keras.layers.experimental.SyncBatchNormalization` endpoint is deprecated and will be removed in a future release. Please use `tf.keras.layers.BatchNormalization` with parameter `synchronized` set to True.
# WARNING:tensorflow:`tf.keras.layers.experimental.SyncBatchNormalization` endpoint is deprecated and will be removed in a future release. Please use `tf.keras.layers.BatchNormalization` with parameter `synchronized` set to True.
# W0402 00:51:27.781544 140151839905600 batch_normalization.py:1426] `tf.keras.layers.experimental.SyncBatchNormalization` endpoint is deprecated and will be removed in a future release. Please use `tf.keras.layers.BatchNormalization` with parameter `synchronized` set to True.
# WARNING:tensorflow:`tf.keras.layers.experimental.SyncBatchNormalization` endpoint is deprecated and will be removed in a future release. Please use `tf.keras.layers.BatchNormalization` with parameter `synchronized` set to True.
# W0402 00:51:27.792593 140151839905600 batch_normalization.py:1426] `tf.keras.layers.experimental.SyncBatchNormalization` endpoint is deprecated and will be removed in a future release. Please use `tf.keras.layers.BatchNormalization` with parameter `synchronized` set to True.
# WARNING:tensorflow:`tf.keras.layers.experimental.SyncBatchNormalization` endpoint is deprecated and will be removed in a future release. Please use `tf.keras.layers.BatchNormalization` with parameter `synchronized` set to True.
# W0402 00:51:27.806379 140151839905600 batch_normalization.py:1426] `tf.keras.layers.experimental.SyncBatchNormalization` endpoint is deprecated and will be removed in a future release. Please use `tf.keras.layers.BatchNormalization` with parameter `synchronized` set to True.
# WARNING:tensorflow:`tf.keras.layers.experimental.SyncBatchNormalization` endpoint is deprecated and will be removed in a future release. Please use `tf.keras.layers.BatchNormalization` with parameter `synchronized` set to True.
# W0402 00:51:27.818634 140151839905600 batch_normalization.py:1426] `tf.keras.layers.experimental.SyncBatchNormalization` endpoint is deprecated and will be removed in a future release. Please use `tf.keras.layers.BatchNormalization` with parameter `synchronized` set to True.
# WARNING:tensorflow:`tf.keras.layers.experimental.SyncBatchNormalization` endpoint is deprecated and will be removed in a future release. Please use `tf.keras.layers.BatchNormalization` with parameter `synchronized` set to True.
# W0402 00:51:27.826440 140151839905600 batch_normalization.py:1426] `tf.keras.layers.experimental.SyncBatchNormalization` endpoint is deprecated and will be removed in a future release. Please use `tf.keras.layers.BatchNormalization` with parameter `synchronized` set to True.
# WARNING:tensorflow:`tf.keras.layers.experimental.SyncBatchNormalization` endpoint is deprecated and will be removed in a future release. Please use `tf.keras.layers.BatchNormalization` with parameter `synchronized` set to True.
# W0402 00:51:27.835923 140151839905600 batch_normalization.py:1426] `tf.keras.layers.experimental.SyncBatchNormalization` endpoint is deprecated and will be removed in a future release. Please use `tf.keras.layers.BatchNormalization` with parameter `synchronized` set to True.
# WARNING:tensorflow:`tf.keras.layers.experimental.SyncBatchNormalization` endpoint is deprecated and will be removed in a future release. Please use `tf.keras.layers.BatchNormalization` with parameter `synchronized` set to True.
# W0402 00:51:27.843614 140151839905600 batch_normalization.py:1426] `tf.keras.layers.experimental.SyncBatchNormalization` endpoint is deprecated and will be removed in a future release. Please use `tf.keras.layers.BatchNormalization` with parameter `synchronized` set to True.
# WARNING:tensorflow:`tf.keras.layers.experimental.SyncBatchNormalization` endpoint is deprecated and will be removed in a future release. Please use `tf.keras.layers.BatchNormalization` with parameter `synchronized` set to True.
# W0402 00:51:27.853602 140151839905600 batch_normalization.py:1426] `tf.keras.layers.experimental.SyncBatchNormalization` endpoint is deprecated and will be removed in a future release. Please use `tf.keras.layers.BatchNormalization` with parameter `synchronized` set to True.
# WARNING:tensorflow:`tf.keras.layers.experimental.SyncBatchNormalization` endpoint is deprecated and will be removed in a future release. Please use `tf.keras.layers.BatchNormalization` with parameter `synchronized` set to True.
# W0402 00:51:27.871434 140151839905600 batch_normalization.py:1426] `tf.keras.layers.experimental.SyncBatchNormalization` endpoint is deprecated and will be removed in a future release. Please use `tf.keras.layers.BatchNormalization` with parameter `synchronized` set to True.
# WARNING:tensorflow:`tf.keras.layers.experimental.SyncBatchNormalization` endpoint is deprecated and will be removed in a future release. Please use `tf.keras.layers.BatchNormalization` with parameter `synchronized` set to True.
# W0402 00:51:27.882022 140151839905600 batch_normalization.py:1426] `tf.keras.layers.experimental.SyncBatchNormalization` endpoint is deprecated and will be removed in a future release. Please use `tf.keras.layers.BatchNormalization` with parameter `synchronized` set to True.
# WARNING:tensorflow:`tf.keras.layers.experimental.SyncBatchNormalization` endpoint is deprecated and will be removed in a future release. Please use `tf.keras.layers.BatchNormalization` with parameter `synchronized` set to True.
# W0402 00:51:27.893592 140151839905600 batch_normalization.py:1426] `tf.keras.layers.experimental.SyncBatchNormalization` endpoint is deprecated and will be removed in a future release. Please use `tf.keras.layers.BatchNormalization` with parameter `synchronized` set to True.
# WARNING:tensorflow:`tf.keras.layers.experimental.SyncBatchNormalization` endpoint is deprecated and will be removed in a future release. Please use `tf.keras.layers.BatchNormalization` with parameter `synchronized` set to True.
# W0402 00:51:27.901257 140151839905600 batch_normalization.py:1426] `tf.keras.layers.experimental.SyncBatchNormalization` endpoint is deprecated and will be removed in a future release. Please use `tf.keras.layers.BatchNormalization` with parameter `synchronized` set to True.
# WARNING:tensorflow:`tf.keras.layers.experimental.SyncBatchNormalization` endpoint is deprecated and will be removed in a future release. Please use `tf.keras.layers.BatchNormalization` with parameter `synchronized` set to True.
# W0402 00:51:27.917035 140151839905600 batch_normalization.py:1426] `tf.keras.layers.experimental.SyncBatchNormalization` endpoint is deprecated and will be removed in a future release. Please use `tf.keras.layers.BatchNormalization` with parameter `synchronized` set to True.
# WARNING:tensorflow:`tf.keras.layers.experimental.SyncBatchNormalization` endpoint is deprecated and will be removed in a future release. Please use `tf.keras.layers.BatchNormalization` with parameter `synchronized` set to True.
# W0402 00:51:27.927728 140151839905600 batch_normalization.py:1426] `tf.keras.layers.experimental.SyncBatchNormalization` endpoint is deprecated and will be removed in a future release. Please use `tf.keras.layers.BatchNormalization` with parameter `synchronized` set to True.
# WARNING:tensorflow:`tf.keras.layers.experimental.SyncBatchNormalization` endpoint is deprecated and will be removed in a future release. Please use `tf.keras.layers.BatchNormalization` with parameter `synchronized` set to True.
# W0402 00:51:27.943977 140151839905600 batch_normalization.py:1426] `tf.keras.layers.experimental.SyncBatchNormalization` endpoint is deprecated and will be removed in a future release. Please use `tf.keras.layers.BatchNormalization` with parameter `synchronized` set to True.
# WARNING:tensorflow:`tf.keras.layers.experimental.SyncBatchNormalization` endpoint is deprecated and will be removed in a future release. Please use `tf.keras.layers.BatchNormalization` with parameter `synchronized` set to True.
# W0402 00:51:27.953754 140151839905600 batch_normalization.py:1426] `tf.keras.layers.experimental.SyncBatchNormalization` endpoint is deprecated and will be removed in a future release. Please use `tf.keras.layers.BatchNormalization` with parameter `synchronized` set to True.
# WARNING:tensorflow:`tf.keras.layers.experimental.SyncBatchNormalization` endpoint is deprecated and will be removed in a future release. Please use `tf.keras.layers.BatchNormalization` with parameter `synchronized` set to True.
# W0402 00:51:27.966259 140151839905600 batch_normalization.py:1426] `tf.keras.layers.experimental.SyncBatchNormalization` endpoint is deprecated and will be removed in a future release. Please use `tf.keras.layers.BatchNormalization` with parameter `synchronized` set to True.
# WARNING:tensorflow:`tf.keras.layers.experimental.SyncBatchNormalization` endpoint is deprecated and will be removed in a future release. Please use `tf.keras.layers.BatchNormalization` with parameter `synchronized` set to True.
# W0402 00:51:27.975101 140151839905600 batch_normalization.py:1426] `tf.keras.layers.experimental.SyncBatchNormalization` endpoint is deprecated and will be removed in a future release. Please use `tf.keras.layers.BatchNormalization` with parameter `synchronized` set to True.
# WARNING:tensorflow:`tf.keras.layers.experimental.SyncBatchNormalization` endpoint is deprecated and will be removed in a future release. Please use `tf.keras.layers.BatchNormalization` with parameter `synchronized` set to True.
# W0402 00:51:27.983010 140151839905600 batch_normalization.py:1426] `tf.keras.layers.experimental.SyncBatchNormalization` endpoint is deprecated and will be removed in a future release. Please use `tf.keras.layers.BatchNormalization` with parameter `synchronized` set to True.
# WARNING:tensorflow:`tf.keras.layers.experimental.SyncBatchNormalization` endpoint is deprecated and will be removed in a future release. Please use `tf.keras.layers.BatchNormalization` with parameter `synchronized` set to True.
# W0402 00:51:27.993606 140151839905600 batch_normalization.py:1426] `tf.keras.layers.experimental.SyncBatchNormalization` endpoint is deprecated and will be removed in a future release. Please use `tf.keras.layers.BatchNormalization` with parameter `synchronized` set to True.
# WARNING:tensorflow:`tf.keras.layers.experimental.SyncBatchNormalization` endpoint is deprecated and will be removed in a future release. Please use `tf.keras.layers.BatchNormalization` with parameter `synchronized` set to True.
# W0402 00:51:28.006547 140151839905600 batch_normalization.py:1426] `tf.keras.layers.experimental.SyncBatchNormalization` endpoint is deprecated and will be removed in a future release. Please use `tf.keras.layers.BatchNormalization` with parameter `synchronized` set to True.
# WARNING:tensorflow:`tf.keras.layers.experimental.SyncBatchNormalization` endpoint is deprecated and will be removed in a future release. Please use `tf.keras.layers.BatchNormalization` with parameter `synchronized` set to True.
# W0402 00:51:28.022206 140151839905600 batch_normalization.py:1426] `tf.keras.layers.experimental.SyncBatchNormalization` endpoint is deprecated and will be removed in a future release. Please use `tf.keras.layers.BatchNormalization` with parameter `synchronized` set to True.
# WARNING:tensorflow:`tf.keras.layers.experimental.SyncBatchNormalization` endpoint is deprecated and will be removed in a future release. Please use `tf.keras.layers.BatchNormalization` with parameter `synchronized` set to True.
# W0402 00:51:28.028763 140151839905600 batch_normalization.py:1426] `tf.keras.layers.experimental.SyncBatchNormalization` endpoint is deprecated and will be removed in a future release. Please use `tf.keras.layers.BatchNormalization` with parameter `synchronized` set to True.
# WARNING:tensorflow:`tf.keras.layers.experimental.SyncBatchNormalization` endpoint is deprecated and will be removed in a future release. Please use `tf.keras.layers.BatchNormalization` with parameter `synchronized` set to True.
# W0402 00:51:28.045655 140151839905600 batch_normalization.py:1426] `tf.keras.layers.experimental.SyncBatchNormalization` endpoint is deprecated and will be removed in a future release. Please use `tf.keras.layers.BatchNormalization` with parameter `synchronized` set to True.
# WARNING:tensorflow:`tf.keras.layers.experimental.SyncBatchNormalization` endpoint is deprecated and will be removed in a future release. Please use `tf.keras.layers.BatchNormalization` with parameter `synchronized` set to True.
# W0402 00:51:28.053590 140151839905600 batch_normalization.py:1426] `tf.keras.layers.experimental.SyncBatchNormalization` endpoint is deprecated and will be removed in a future release. Please use `tf.keras.layers.BatchNormalization` with parameter `synchronized` set to True.
# WARNING:tensorflow:`tf.keras.layers.experimental.SyncBatchNormalization` endpoint is deprecated and will be removed in a future release. Please use `tf.keras.layers.BatchNormalization` with parameter `synchronized` set to True.
# W0402 00:51:28.067829 140151839905600 batch_normalization.py:1426] `tf.keras.layers.experimental.SyncBatchNormalization` endpoint is deprecated and will be removed in a future release. Please use `tf.keras.layers.BatchNormalization` with parameter `synchronized` set to True.
# WARNING:tensorflow:`tf.keras.layers.experimental.SyncBatchNormalization` endpoint is deprecated and will be removed in a future release. Please use `tf.keras.layers.BatchNormalization` with parameter `synchronized` set to True.
# W0402 00:51:28.080369 140151839905600 batch_normalization.py:1426] `tf.keras.layers.experimental.SyncBatchNormalization` endpoint is deprecated and will be removed in a future release. Please use `tf.keras.layers.BatchNormalization` with parameter `synchronized` set to True.
# WARNING:tensorflow:`tf.keras.layers.experimental.SyncBatchNormalization` endpoint is deprecated and will be removed in a future release. Please use `tf.keras.layers.BatchNormalization` with parameter `synchronized` set to True.
# W0402 00:51:28.089449 140151839905600 batch_normalization.py:1426] `tf.keras.layers.experimental.SyncBatchNormalization` endpoint is deprecated and will be removed in a future release. Please use `tf.keras.layers.BatchNormalization` with parameter `synchronized` set to True.
# WARNING:tensorflow:`tf.keras.layers.experimental.SyncBatchNormalization` endpoint is deprecated and will be removed in a future release. Please use `tf.keras.layers.BatchNormalization` with parameter `synchronized` set to True.
# W0402 00:51:28.098376 140151839905600 batch_normalization.py:1426] `tf.keras.layers.experimental.SyncBatchNormalization` endpoint is deprecated and will be removed in a future release. Please use `tf.keras.layers.BatchNormalization` with parameter `synchronized` set to True.
# WARNING:tensorflow:`tf.keras.layers.experimental.SyncBatchNormalization` endpoint is deprecated and will be removed in a future release. Please use `tf.keras.layers.BatchNormalization` with parameter `synchronized` set to True.
# W0402 00:51:28.109748 140151839905600 batch_normalization.py:1426] `tf.keras.layers.experimental.SyncBatchNormalization` endpoint is deprecated and will be removed in a future release. Please use `tf.keras.layers.BatchNormalization` with parameter `synchronized` set to True.
# WARNING:tensorflow:`tf.keras.layers.experimental.SyncBatchNormalization` endpoint is deprecated and will be removed in a future release. Please use `tf.keras.layers.BatchNormalization` with parameter `synchronized` set to True.
# W0402 00:51:28.127241 140151839905600 batch_normalization.py:1426] `tf.keras.layers.experimental.SyncBatchNormalization` endpoint is deprecated and will be removed in a future release. Please use `tf.keras.layers.BatchNormalization` with parameter `synchronized` set to True.
# WARNING:tensorflow:`tf.keras.layers.experimental.SyncBatchNormalization` endpoint is deprecated and will be removed in a future release. Please use `tf.keras.layers.BatchNormalization` with parameter `synchronized` set to True.
# W0402 00:51:28.130906 140151839905600 batch_normalization.py:1426] `tf.keras.layers.experimental.SyncBatchNormalization` endpoint is deprecated and will be removed in a future release. Please use `tf.keras.layers.BatchNormalization` with parameter `synchronized` set to True.
# WARNING:tensorflow:`tf.keras.layers.experimental.SyncBatchNormalization` endpoint is deprecated and will be removed in a future release. Please use `tf.keras.layers.BatchNormalization` with parameter `synchronized` set to True.
# W0402 00:51:28.150394 140151839905600 batch_normalization.py:1426] `tf.keras.layers.experimental.SyncBatchNormalization` endpoint is deprecated and will be removed in a future release. Please use `tf.keras.layers.BatchNormalization` with parameter `synchronized` set to True.
# WARNING:tensorflow:`tf.keras.layers.experimental.SyncBatchNormalization` endpoint is deprecated and will be removed in a future release. Please use `tf.keras.layers.BatchNormalization` with parameter `synchronized` set to True.
# W0402 00:51:28.158260 140151839905600 batch_normalization.py:1426] `tf.keras.layers.experimental.SyncBatchNormalization` endpoint is deprecated and will be removed in a future release. Please use `tf.keras.layers.BatchNormalization` with parameter `synchronized` set to True.
# WARNING:tensorflow:`tf.keras.layers.experimental.SyncBatchNormalization` endpoint is deprecated and will be removed in a future release. Please use `tf.keras.layers.BatchNormalization` with parameter `synchronized` set to True.
# W0402 00:51:28.172369 140151839905600 batch_normalization.py:1426] `tf.keras.layers.experimental.SyncBatchNormalization` endpoint is deprecated and will be removed in a future release. Please use `tf.keras.layers.BatchNormalization` with parameter `synchronized` set to True.
# WARNING:tensorflow:`tf.keras.layers.experimental.SyncBatchNormalization` endpoint is deprecated and will be removed in a future release. Please use `tf.keras.layers.BatchNormalization` with parameter `synchronized` set to True.
# W0402 00:51:28.182390 140151839905600 batch_normalization.py:1426] `tf.keras.layers.experimental.SyncBatchNormalization` endpoint is deprecated and will be removed in a future release. Please use `tf.keras.layers.BatchNormalization` with parameter `synchronized` set to True.
# WARNING:tensorflow:`tf.keras.layers.experimental.SyncBatchNormalization` endpoint is deprecated and will be removed in a future release. Please use `tf.keras.layers.BatchNormalization` with parameter `synchronized` set to True.
# W0402 00:51:28.197578 140151839905600 batch_normalization.py:1426] `tf.keras.layers.experimental.SyncBatchNormalization` endpoint is deprecated and will be removed in a future release. Please use `tf.keras.layers.BatchNormalization` with parameter `synchronized` set to True.
# WARNING:tensorflow:`tf.keras.layers.experimental.SyncBatchNormalization` endpoint is deprecated and will be removed in a future release. Please use `tf.keras.layers.BatchNormalization` with parameter `synchronized` set to True.
# W0402 00:51:28.211794 140151839905600 batch_normalization.py:1426] `tf.keras.layers.experimental.SyncBatchNormalization` endpoint is deprecated and will be removed in a future release. Please use `tf.keras.layers.BatchNormalization` with parameter `synchronized` set to True.
# WARNING:tensorflow:`tf.keras.layers.experimental.SyncBatchNormalization` endpoint is deprecated and will be removed in a future release. Please use `tf.keras.layers.BatchNormalization` with parameter `synchronized` set to True.
# W0402 00:51:28.272048 140151839905600 batch_normalization.py:1426] `tf.keras.layers.experimental.SyncBatchNormalization` endpoint is deprecated and will be removed in a future release. Please use `tf.keras.layers.BatchNormalization` with parameter `synchronized` set to True.
# WARNING:tensorflow:`tf.keras.layers.experimental.SyncBatchNormalization` endpoint is deprecated and will be removed in a future release. Please use `tf.keras.layers.BatchNormalization` with parameter `synchronized` set to True.
# W0402 00:51:28.279522 140151839905600 batch_normalization.py:1426] `tf.keras.layers.experimental.SyncBatchNormalization` endpoint is deprecated and will be removed in a future release. Please use `tf.keras.layers.BatchNormalization` with parameter `synchronized` set to True.
# WARNING:tensorflow:`tf.keras.layers.experimental.SyncBatchNormalization` endpoint is deprecated and will be removed in a future release. Please use `tf.keras.layers.BatchNormalization` with parameter `synchronized` set to True.
# W0402 00:51:28.296084 140151839905600 batch_normalization.py:1426] `tf.keras.layers.experimental.SyncBatchNormalization` endpoint is deprecated and will be removed in a future release. Please use `tf.keras.layers.BatchNormalization` with parameter `synchronized` set to True.
# WARNING:tensorflow:`tf.keras.layers.experimental.SyncBatchNormalization` endpoint is deprecated and will be removed in a future release. Please use `tf.keras.layers.BatchNormalization` with parameter `synchronized` set to True.
# W0402 00:51:28.306273 140151839905600 batch_normalization.py:1426] `tf.keras.layers.experimental.SyncBatchNormalization` endpoint is deprecated and will be removed in a future release. Please use `tf.keras.layers.BatchNormalization` with parameter `synchronized` set to True.
# WARNING:tensorflow:`tf.keras.layers.experimental.SyncBatchNormalization` endpoint is deprecated and will be removed in a future release. Please use `tf.keras.layers.BatchNormalization` with parameter `synchronized` set to True.
# W0402 00:51:28.314214 140151839905600 batch_normalization.py:1426] `tf.keras.layers.experimental.SyncBatchNormalization` endpoint is deprecated and will be removed in a future release. Please use `tf.keras.layers.BatchNormalization` with parameter `synchronized` set to True.
# WARNING:tensorflow:`tf.keras.layers.experimental.SyncBatchNormalization` endpoint is deprecated and will be removed in a future release. Please use `tf.keras.layers.BatchNormalization` with parameter `synchronized` set to True.
# W0402 00:51:28.335327 140151839905600 batch_normalization.py:1426] `tf.keras.layers.experimental.SyncBatchNormalization` endpoint is deprecated and will be removed in a future release. Please use `tf.keras.layers.BatchNormalization` with parameter `synchronized` set to True.
# WARNING:tensorflow:`tf.keras.layers.experimental.SyncBatchNormalization` endpoint is deprecated and will be removed in a future release. Please use `tf.keras.layers.BatchNormalization` with parameter `synchronized` set to True.
# W0402 00:51:28.344497 140151839905600 batch_normalization.py:1426] `tf.keras.layers.experimental.SyncBatchNormalization` endpoint is deprecated and will be removed in a future release. Please use `tf.keras.layers.BatchNormalization` with parameter `synchronized` set to True.
# WARNING:tensorflow:`tf.keras.layers.experimental.SyncBatchNormalization` endpoint is deprecated and will be removed in a future release. Please use `tf.keras.layers.BatchNormalization` with parameter `synchronized` set to True.
# W0402 00:51:28.357706 140151839905600 batch_normalization.py:1426] `tf.keras.layers.experimental.SyncBatchNormalization` endpoint is deprecated and will be removed in a future release. Please use `tf.keras.layers.BatchNormalization` with parameter `synchronized` set to True.
# WARNING:tensorflow:`tf.keras.layers.experimental.SyncBatchNormalization` endpoint is deprecated and will be removed in a future release. Please use `tf.keras.layers.BatchNormalization` with parameter `synchronized` set to True.
# W0402 00:51:28.363711 140151839905600 batch_normalization.py:1426] `tf.keras.layers.experimental.SyncBatchNormalization` endpoint is deprecated and will be removed in a future release. Please use `tf.keras.layers.BatchNormalization` with parameter `synchronized` set to True.
# WARNING:tensorflow:`tf.keras.layers.experimental.SyncBatchNormalization` endpoint is deprecated and will be removed in a future release. Please use `tf.keras.layers.BatchNormalization` with parameter `synchronized` set to True.
# W0402 00:51:28.385746 140151839905600 batch_normalization.py:1426] `tf.keras.layers.experimental.SyncBatchNormalization` endpoint is deprecated and will be removed in a future release. Please use `tf.keras.layers.BatchNormalization` with parameter `synchronized` set to True.
# WARNING:tensorflow:`tf.keras.layers.experimental.SyncBatchNormalization` endpoint is deprecated and will be removed in a future release. Please use `tf.keras.layers.BatchNormalization` with parameter `synchronized` set to True.
# W0402 00:51:28.396384 140151839905600 batch_normalization.py:1426] `tf.keras.layers.experimental.SyncBatchNormalization` endpoint is deprecated and will be removed in a future release. Please use `tf.keras.layers.BatchNormalization` with parameter `synchronized` set to True.
# WARNING:tensorflow:`tf.keras.layers.experimental.SyncBatchNormalization` endpoint is deprecated and will be removed in a future release. Please use `tf.keras.layers.BatchNormalization` with parameter `synchronized` set to True.
# W0402 00:51:28.407698 140151839905600 batch_normalization.py:1426] `tf.keras.layers.experimental.SyncBatchNormalization` endpoint is deprecated and will be removed in a future release. Please use `tf.keras.layers.BatchNormalization` with parameter `synchronized` set to True.
# WARNING:tensorflow:`tf.keras.layers.experimental.SyncBatchNormalization` endpoint is deprecated and will be removed in a future release. Please use `tf.keras.layers.BatchNormalization` with parameter `synchronized` set to True.
# W0402 00:51:28.414522 140151839905600 batch_normalization.py:1426] `tf.keras.layers.experimental.SyncBatchNormalization` endpoint is deprecated and will be removed in a future release. Please use `tf.keras.layers.BatchNormalization` with parameter `synchronized` set to True.
# WARNING:tensorflow:`tf.keras.layers.experimental.SyncBatchNormalization` endpoint is deprecated and will be removed in a future release. Please use `tf.keras.layers.BatchNormalization` with parameter `synchronized` set to True.
# W0402 00:51:28.420437 140151839905600 batch_normalization.py:1426] `tf.keras.layers.experimental.SyncBatchNormalization` endpoint is deprecated and will be removed in a future release. Please use `tf.keras.layers.BatchNormalization` with parameter `synchronized` set to True.
# WARNING:tensorflow:`tf.keras.layers.experimental.SyncBatchNormalization` endpoint is deprecated and will be removed in a future release. Please use `tf.keras.layers.BatchNormalization` with parameter `synchronized` set to True.
# W0402 00:51:28.424060 140151839905600 batch_normalization.py:1426] `tf.keras.layers.experimental.SyncBatchNormalization` endpoint is deprecated and will be removed in a future release. Please use `tf.keras.layers.BatchNormalization` with parameter `synchronized` set to True.
# WARNING:tensorflow:`tf.keras.layers.experimental.SyncBatchNormalization` endpoint is deprecated and will be removed in a future release. Please use `tf.keras.layers.BatchNormalization` with parameter `synchronized` set to True.
# W0402 00:51:28.429496 140151839905600 batch_normalization.py:1426] `tf.keras.layers.experimental.SyncBatchNormalization` endpoint is deprecated and will be removed in a future release. Please use `tf.keras.layers.BatchNormalization` with parameter `synchronized` set to True.
# WARNING:tensorflow:`tf.keras.layers.experimental.SyncBatchNormalization` endpoint is deprecated and will be removed in a future release. Please use `tf.keras.layers.BatchNormalization` with parameter `synchronized` set to True.
# W0402 00:51:28.440336 140151839905600 batch_normalization.py:1426] `tf.keras.layers.experimental.SyncBatchNormalization` endpoint is deprecated and will be removed in a future release. Please use `tf.keras.layers.BatchNormalization` with parameter `synchronized` set to True.
# WARNING:tensorflow:`tf.keras.layers.experimental.SyncBatchNormalization` endpoint is deprecated and will be removed in a future release. Please use `tf.keras.layers.BatchNormalization` with parameter `synchronized` set to True.
# W0402 00:51:28.449092 140151839905600 batch_normalization.py:1426] `tf.keras.layers.experimental.SyncBatchNormalization` endpoint is deprecated and will be removed in a future release. Please use `tf.keras.layers.BatchNormalization` with parameter `synchronized` set to True.
# WARNING:tensorflow:`tf.keras.layers.experimental.SyncBatchNormalization` endpoint is deprecated and will be removed in a future release. Please use `tf.keras.layers.BatchNormalization` with parameter `synchronized` set to True.
# W0402 00:51:28.479110 140151839905600 batch_normalization.py:1426] `tf.keras.layers.experimental.SyncBatchNormalization` endpoint is deprecated and will be removed in a future release. Please use `tf.keras.layers.BatchNormalization` with parameter `synchronized` set to True.
# WARNING:tensorflow:`tf.keras.layers.experimental.SyncBatchNormalization` endpoint is deprecated and will be removed in a future release. Please use `tf.keras.layers.BatchNormalization` with parameter `synchronized` set to True.
# W0402 00:51:28.491776 140151839905600 batch_normalization.py:1426] `tf.keras.layers.experimental.SyncBatchNormalization` endpoint is deprecated and will be removed in a future release. Please use `tf.keras.layers.BatchNormalization` with parameter `synchronized` set to True.
# WARNING:tensorflow:`tf.keras.layers.experimental.SyncBatchNormalization` endpoint is deprecated and will be removed in a future release. Please use `tf.keras.layers.BatchNormalization` with parameter `synchronized` set to True.
# W0402 00:51:28.506243 140151839905600 batch_normalization.py:1426] `tf.keras.layers.experimental.SyncBatchNormalization` endpoint is deprecated and will be removed in a future release. Please use `tf.keras.layers.BatchNormalization` with parameter `synchronized` set to True.
# WARNING:tensorflow:`tf.keras.layers.experimental.SyncBatchNormalization` endpoint is deprecated and will be removed in a future release. Please use `tf.keras.layers.BatchNormalization` with parameter `synchronized` set to True.
# W0402 00:51:28.509656 140151839905600 batch_normalization.py:1426] `tf.keras.layers.experimental.SyncBatchNormalization` endpoint is deprecated and will be removed in a future release. Please use `tf.keras.layers.BatchNormalization` with parameter `synchronized` set to True.
# WARNING:tensorflow:`tf.keras.layers.experimental.SyncBatchNormalization` endpoint is deprecated and will be removed in a future release. Please use `tf.keras.layers.BatchNormalization` with parameter `synchronized` set to True.
# W0402 00:51:28.524685 140151839905600 batch_normalization.py:1426] `tf.keras.layers.experimental.SyncBatchNormalization` endpoint is deprecated and will be removed in a future release. Please use `tf.keras.layers.BatchNormalization` with parameter `synchronized` set to True.
# W0402 00:51:28.541125 140151839905600 model_builder.py:1112] Building experimental DeepMAC meta-arch. Some features may be omitted.
# WARNING:tensorflow:`tf.keras.layers.experimental.SyncBatchNormalization` endpoint is deprecated and will be removed in a future release. Please use `tf.keras.layers.BatchNormalization` with parameter `synchronized` set to True.
# W0402 00:51:28.663439 140151839905600 batch_normalization.py:1426] `tf.keras.layers.experimental.SyncBatchNormalization` endpoint is deprecated and will be removed in a future release. Please use `tf.keras.layers.BatchNormalization` with parameter `synchronized` set to True.
# WARNING:tensorflow:`tf.keras.layers.experimental.SyncBatchNormalization` endpoint is deprecated and will be removed in a future release. Please use `tf.keras.layers.BatchNormalization` with parameter `synchronized` set to True.
# W0402 00:51:28.688528 140151839905600 batch_normalization.py:1426] `tf.keras.layers.experimental.SyncBatchNormalization` endpoint is deprecated and will be removed in a future release. Please use `tf.keras.layers.BatchNormalization` with parameter `synchronized` set to True.
# WARNING:tensorflow:`tf.keras.layers.experimental.SyncBatchNormalization` endpoint is deprecated and will be removed in a future release. Please use `tf.keras.layers.BatchNormalization` with parameter `synchronized` set to True.
# W0402 00:51:28.704601 140151839905600 batch_normalization.py:1426] `tf.keras.layers.experimental.SyncBatchNormalization` endpoint is deprecated and will be removed in a future release. Please use `tf.keras.layers.BatchNormalization` with parameter `synchronized` set to True.
# WARNING:tensorflow:`tf.keras.layers.experimental.SyncBatchNormalization` endpoint is deprecated and will be removed in a future release. Please use `tf.keras.layers.BatchNormalization` with parameter `synchronized` set to True.
# W0402 00:51:28.715584 140151839905600 batch_normalization.py:1426] `tf.keras.layers.experimental.SyncBatchNormalization` endpoint is deprecated and will be removed in a future release. Please use `tf.keras.layers.BatchNormalization` with parameter `synchronized` set to True.
# WARNING:tensorflow:`tf.keras.layers.experimental.SyncBatchNormalization` endpoint is deprecated and will be removed in a future release. Please use `tf.keras.layers.BatchNormalization` with parameter `synchronized` set to True.
# W0402 00:51:28.744127 140151839905600 batch_normalization.py:1426] `tf.keras.layers.experimental.SyncBatchNormalization` endpoint is deprecated and will be removed in a future release. Please use `tf.keras.layers.BatchNormalization` with parameter `synchronized` set to True.
# WARNING:tensorflow:`tf.keras.layers.experimental.SyncBatchNormalization` endpoint is deprecated and will be removed in a future release. Please use `tf.keras.layers.BatchNormalization` with parameter `synchronized` set to True.
# ...
# I0402 00:51:57.924275 140151839905600 ssd_efficientnet_bifpn_feature_extractor.py:150] EfficientDet EfficientNet backbone version: efficientnet-b5
# I0402 00:51:57.924450 140151839905600 ssd_efficientnet_bifpn_feature_extractor.py:152] EfficientDet BiFPN num filters: 288
# I0402 00:51:57.924540 140151839905600 ssd_efficientnet_bifpn_feature_extractor.py:153] EfficientDet BiFPN num iterations: 7
# I0402 00:51:57.927340 140151839905600 efficientnet_model.py:143] round_filter input=32 output=48
# I0402 00:51:57.954157 140151839905600 efficientnet_model.py:143] round_filter input=32 output=48
# I0402 00:51:57.954278 140151839905600 efficientnet_model.py:143] round_filter input=16 output=24
# I0402 00:51:58.266763 140151839905600 efficientnet_model.py:143] round_filter input=16 output=24
# I0402 00:51:58.266954 140151839905600 efficientnet_model.py:143] round_filter input=24 output=40
# I0402 00:51:58.917695 140151839905600 efficientnet_model.py:143] round_filter input=24 output=40
# I0402 00:51:58.917899 140151839905600 efficientnet_model.py:143] round_filter input=40 output=64
# I0402 00:51:59.536050 140151839905600 efficientnet_model.py:143] round_filter input=40 output=64
# I0402 00:51:59.536206 140151839905600 efficientnet_model.py:143] round_filter input=80 output=128
# I0402 00:52:00.445068 140151839905600 efficientnet_model.py:143] round_filter input=80 output=128
# I0402 00:52:00.445255 140151839905600 efficientnet_model.py:143] round_filter input=112 output=176
# I0402 00:52:01.086605 140151839905600 efficientnet_model.py:143] round_filter input=112 output=176
# I0402 00:52:01.086767 140151839905600 efficientnet_model.py:143] round_filter input=192 output=304
# I0402 00:52:01.904512 140151839905600 efficientnet_model.py:143] round_filter input=192 output=304
# I0402 00:52:01.904670 140151839905600 efficientnet_model.py:143] round_filter input=320 output=512
# I0402 00:52:02.179501 140151839905600 efficientnet_model.py:143] round_filter input=1280 output=2048
# I0402 00:52:02.228598 140151839905600 efficientnet_model.py:453] Building model efficientnet with params ModelConfig(width_coefficient=1.6, depth_coefficient=2.2, resolution=456, dropout_rate=0.4, blocks=(BlockConfig(input_filters=32, output_filters=16, kernel_size=3, num_repeat=1, expand_ratio=1, strides=(1, 1), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=16, output_filters=24, kernel_size=3, num_repeat=2, expand_ratio=6, strides=(2, 2), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=24, output_filters=40, kernel_size=5, num_repeat=2, expand_ratio=6, strides=(2, 2), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=40, output_filters=80, kernel_size=3, num_repeat=3, expand_ratio=6, strides=(2, 2), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=80, output_filters=112, kernel_size=5, num_repeat=3, expand_ratio=6, strides=(1, 1), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=112, output_filters=192, kernel_size=5, num_repeat=4, expand_ratio=6, strides=(2, 2), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=192, output_filters=320, kernel_size=3, num_repeat=1, expand_ratio=6, strides=(1, 1), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise')), stem_base_filters=32, top_base_filters=1280, activation='simple_swish', batch_norm='default', bn_momentum=0.99, bn_epsilon=0.001, weight_decay=5e-06, drop_connect_rate=0.2, depth_divisor=8, min_depth=None, use_se=True, input_channels=3, num_classes=1000, model_name='efficientnet', rescale_input=False, data_format='channels_last', dtype='float32')
# I0402 00:52:02.309859 140151839905600 ssd_efficientnet_bifpn_feature_extractor.py:150] EfficientDet EfficientNet backbone version: efficientnet-b6
# I0402 00:52:02.310016 140151839905600 ssd_efficientnet_bifpn_feature_extractor.py:152] EfficientDet BiFPN num filters: 384
# I0402 00:52:02.310081 140151839905600 ssd_efficientnet_bifpn_feature_extractor.py:153] EfficientDet BiFPN num iterations: 8
# I0402 00:52:02.311685 140151839905600 efficientnet_model.py:143] round_filter input=32 output=56
# I0402 00:52:02.330785 140151839905600 efficientnet_model.py:143] round_filter input=32 output=56
# I0402 00:52:02.330911 140151839905600 efficientnet_model.py:143] round_filter input=16 output=32
# I0402 00:52:02.550572 140151839905600 efficientnet_model.py:143] round_filter input=16 output=32
# I0402 00:52:02.550698 140151839905600 efficientnet_model.py:143] round_filter input=24 output=40
# I0402 00:52:03.078557 140151839905600 efficientnet_model.py:143] round_filter input=24 output=40
# I0402 00:52:03.078718 140151839905600 efficientnet_model.py:143] round_filter input=40 output=72
# I0402 00:52:03.629060 140151839905600 efficientnet_model.py:143] round_filter input=40 output=72
# I0402 00:52:03.629218 140151839905600 efficientnet_model.py:143] round_filter input=80 output=144
# I0402 00:52:04.358671 140151839905600 efficientnet_model.py:143] round_filter input=80 output=144
# I0402 00:52:04.358830 140151839905600 efficientnet_model.py:143] round_filter input=112 output=200
# I0402 00:52:05.084031 140151839905600 efficientnet_model.py:143] round_filter input=112 output=200
# I0402 00:52:05.084297 140151839905600 efficientnet_model.py:143] round_filter input=192 output=344
# I0402 00:52:06.094934 140151839905600 efficientnet_model.py:143] round_filter input=192 output=344
# I0402 00:52:06.095090 140151839905600 efficientnet_model.py:143] round_filter input=320 output=576
# I0402 00:52:06.380587 140151839905600 efficientnet_model.py:143] round_filter input=1280 output=2304
# I0402 00:52:06.416688 140151839905600 efficientnet_model.py:453] Building model efficientnet with params ModelConfig(width_coefficient=1.8, depth_coefficient=2.6, resolution=528, dropout_rate=0.5, blocks=(BlockConfig(input_filters=32, output_filters=16, kernel_size=3, num_repeat=1, expand_ratio=1, strides=(1, 1), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=16, output_filters=24, kernel_size=3, num_repeat=2, expand_ratio=6, strides=(2, 2), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=24, output_filters=40, kernel_size=5, num_repeat=2, expand_ratio=6, strides=(2, 2), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=40, output_filters=80, kernel_size=3, num_repeat=3, expand_ratio=6, strides=(2, 2), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=80, output_filters=112, kernel_size=5, num_repeat=3, expand_ratio=6, strides=(1, 1), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=112, output_filters=192, kernel_size=5, num_repeat=4, expand_ratio=6, strides=(2, 2), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=192, output_filters=320, kernel_size=3, num_repeat=1, expand_ratio=6, strides=(1, 1), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise')), stem_base_filters=32, top_base_filters=1280, activation='simple_swish', batch_norm='default', bn_momentum=0.99, bn_epsilon=0.001, weight_decay=5e-06, drop_connect_rate=0.2, depth_divisor=8, min_depth=None, use_se=True, input_channels=3, num_classes=1000, model_name='efficientnet', rescale_input=False, data_format='channels_last', dtype='float32')
# I0402 00:52:06.511228 140151839905600 ssd_efficientnet_bifpn_feature_extractor.py:150] EfficientDet EfficientNet backbone version: efficientnet-b7
# I0402 00:52:06.511399 140151839905600 ssd_efficientnet_bifpn_feature_extractor.py:152] EfficientDet BiFPN num filters: 384
# I0402 00:52:06.511467 140151839905600 ssd_efficientnet_bifpn_feature_extractor.py:153] EfficientDet BiFPN num iterations: 8
# I0402 00:52:06.513748 140151839905600 efficientnet_model.py:143] round_filter input=32 output=64
# I0402 00:52:06.534100 140151839905600 efficientnet_model.py:143] round_filter input=32 output=64
# I0402 00:52:06.534232 140151839905600 efficientnet_model.py:143] round_filter input=16 output=32
# I0402 00:52:06.817362 140151839905600 efficientnet_model.py:143] round_filter input=16 output=32
# I0402 00:52:06.817541 140151839905600 efficientnet_model.py:143] round_filter input=24 output=48
# I0402 00:52:07.443789 140151839905600 efficientnet_model.py:143] round_filter input=24 output=48
# I0402 00:52:07.444010 140151839905600 efficientnet_model.py:143] round_filter input=40 output=80
# I0402 00:52:08.352056 140151839905600 efficientnet_model.py:143] round_filter input=40 output=80
# I0402 00:52:08.352215 140151839905600 efficientnet_model.py:143] round_filter input=80 output=160
# I0402 00:52:09.242063 140151839905600 efficientnet_model.py:143] round_filter input=80 output=160
# I0402 00:52:09.242220 140151839905600 efficientnet_model.py:143] round_filter input=112 output=224
# I0402 00:52:10.470628 140151839905600 efficientnet_model.py:143] round_filter input=112 output=224
# I0402 00:52:10.470820 140151839905600 efficientnet_model.py:143] round_filter input=192 output=384
# I0402 00:52:12.042464 140151839905600 efficientnet_model.py:143] round_filter input=192 output=384
# I0402 00:52:12.042653 140151839905600 efficientnet_model.py:143] round_filter input=320 output=640
# I0402 00:52:12.544419 140151839905600 efficientnet_model.py:143] round_filter input=1280 output=2560
# I0402 00:52:12.609627 140151839905600 efficientnet_model.py:453] Building model efficientnet with params ModelConfig(width_coefficient=2.0, depth_coefficient=3.1, resolution=600, dropout_rate=0.5, blocks=(BlockConfig(input_filters=32, output_filters=16, kernel_size=3, num_repeat=1, expand_ratio=1, strides=(1, 1), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=16, output_filters=24, kernel_size=3, num_repeat=2, expand_ratio=6, strides=(2, 2), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=24, output_filters=40, kernel_size=5, num_repeat=2, expand_ratio=6, strides=(2, 2), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=40, output_filters=80, kernel_size=3, num_repeat=3, expand_ratio=6, strides=(2, 2), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=80, output_filters=112, kernel_size=5, num_repeat=3, expand_ratio=6, strides=(1, 1), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=112, output_filters=192, kernel_size=5, num_repeat=4, expand_ratio=6, strides=(2, 2), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=192, output_filters=320, kernel_size=3, num_repeat=1, expand_ratio=6, strides=(1, 1), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise')), stem_base_filters=32, top_base_filters=1280, activation='simple_swish', batch_norm='default', bn_momentum=0.99, bn_epsilon=0.001, weight_decay=5e-06, drop_connect_rate=0.2, depth_divisor=8, min_depth=None, use_se=True, input_channels=3, num_classes=1000, model_name='efficientnet', rescale_input=False, data_format='channels_last', dtype='float32')
# INFO:tensorflow:time(__main__.ModelBuilderTF2Test.test_create_ssd_models_from_config): 29.38s
# I0402 00:52:12.778603 140151839905600 test_util.py:2467] time(__main__.ModelBuilderTF2Test.test_create_ssd_models_from_config): 29.38s
# [       OK ] ModelBuilderTF2Test.test_create_ssd_models_from_config
# [ RUN      ] ModelBuilderTF2Test.test_invalid_faster_rcnn_batchnorm_update
# INFO:tensorflow:time(__main__.ModelBuilderTF2Test.test_invalid_faster_rcnn_batchnorm_update): 0.0s
# I0402 00:52:12.814456 140151839905600 test_util.py:2467] time(__main__.ModelBuilderTF2Test.test_invalid_faster_rcnn_batchnorm_update): 0.0s
# [       OK ] ModelBuilderTF2Test.test_invalid_faster_rcnn_batchnorm_update
# [ RUN      ] ModelBuilderTF2Test.test_invalid_first_stage_nms_iou_threshold
# INFO:tensorflow:time(__main__.ModelBuilderTF2Test.test_invalid_first_stage_nms_iou_threshold): 0.0s
# I0402 00:52:12.816811 140151839905600 test_util.py:2467] time(__main__.ModelBuilderTF2Test.test_invalid_first_stage_nms_iou_threshold): 0.0s
# [       OK ] ModelBuilderTF2Test.test_invalid_first_stage_nms_iou_threshold
# [ RUN      ] ModelBuilderTF2Test.test_invalid_model_config_proto
# INFO:tensorflow:time(__main__.ModelBuilderTF2Test.test_invalid_model_config_proto): 0.0s
# I0402 00:52:12.817425 140151839905600 test_util.py:2467] time(__main__.ModelBuilderTF2Test.test_invalid_model_config_proto): 0.0s
# [       OK ] ModelBuilderTF2Test.test_invalid_model_config_proto
# [ RUN      ] ModelBuilderTF2Test.test_invalid_second_stage_batch_size
# INFO:tensorflow:time(__main__.ModelBuilderTF2Test.test_invalid_second_stage_batch_size): 0.0s
# I0402 00:52:12.819346 140151839905600 test_util.py:2467] time(__main__.ModelBuilderTF2Test.test_invalid_second_stage_batch_size): 0.0s
# [       OK ] ModelBuilderTF2Test.test_invalid_second_stage_batch_size
# [ RUN      ] ModelBuilderTF2Test.test_session
# [  SKIPPED ] ModelBuilderTF2Test.test_session
# [ RUN      ] ModelBuilderTF2Test.test_unknown_faster_rcnn_feature_extractor
# INFO:tensorflow:time(__main__.ModelBuilderTF2Test.test_unknown_faster_rcnn_feature_extractor): 0.0s
# I0402 00:52:12.821060 140151839905600 test_util.py:2467] time(__main__.ModelBuilderTF2Test.test_unknown_faster_rcnn_feature_extractor): 0.0s
# [       OK ] ModelBuilderTF2Test.test_unknown_faster_rcnn_feature_extractor
# [ RUN      ] ModelBuilderTF2Test.test_unknown_meta_architecture
# INFO:tensorflow:time(__main__.ModelBuilderTF2Test.test_unknown_meta_architecture): 0.0s
# I0402 00:52:12.821534 140151839905600 test_util.py:2467] time(__main__.ModelBuilderTF2Test.test_unknown_meta_architecture): 0.0s
# [       OK ] ModelBuilderTF2Test.test_unknown_meta_architecture
# [ RUN      ] ModelBuilderTF2Test.test_unknown_ssd_feature_extractor
# INFO:tensorflow:time(__main__.ModelBuilderTF2Test.test_unknown_ssd_feature_extractor): 0.0s
# I0402 00:52:12.822883 140151839905600 test_util.py:2467] time(__main__.ModelBuilderTF2Test.test_unknown_ssd_feature_extractor): 0.0s
# [       OK ] ModelBuilderTF2Test.test_unknown_ssd_feature_extractor
# ----------------------------------------------------------------------
# Ran 24 tests in 49.392s
#
# OK (skipped=1)

# %%
import object_detection

# %%
if os.name =='posix':
    # !wget {PRETRAINED_MODEL_URL}
    # !mv {PRETRAINED_MODEL_NAME+'.tar.gz'} {paths['PRETRAINED_MODEL_PATH']}
    # !cd {paths['PRETRAINED_MODEL_PATH']} && tar -zxvf {PRETRAINED_MODEL_NAME+'.tar.gz'}
if os.name == 'nt':
    wget.download(PRETRAINED_MODEL_URL)
    # !move {PRETRAINED_MODEL_NAME+'.tar.gz'} {paths['PRETRAINED_MODEL_PATH']}
    # !cd {paths['PRETRAINED_MODEL_PATH']} && tar -zxvf {PRETRAINED_MODEL_NAME+'.tar.gz'}
# Out:
# --2023-04-02 00:53:15--  http://download.tensorflow.org/models/object_detection/tf2/20200711/ssd_mobilenet_v2_fpnlite_320x320_coco17_tpu-8.tar.gz
# Resolving download.tensorflow.org (download.tensorflow.org)... 74.125.20.128, 2607:f8b0:400e:c07::80
# Connecting to download.tensorflow.org (download.tensorflow.org)|74.125.20.128|:80... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 20515344 (20M) [application/x-tar]
# Saving to: ‘ssd_mobilenet_v2_fpnlite_320x320_coco17_tpu-8.tar.gz’
#
# ssd_mobilenet_v2_fp 100%[===================>]  19.56M   126MB/s    in 0.2s
#
# 2023-04-02 00:53:15 (126 MB/s) - ‘ssd_mobilenet_v2_fpnlite_320x320_coco17_tpu-8.tar.gz’ saved [20515344/20515344]
#
# ssd_mobilenet_v2_fpnlite_320x320_coco17_tpu-8/
# ssd_mobilenet_v2_fpnlite_320x320_coco17_tpu-8/checkpoint/
# ssd_mobilenet_v2_fpnlite_320x320_coco17_tpu-8/checkpoint/ckpt-0.data-00000-of-00001
# ssd_mobilenet_v2_fpnlite_320x320_coco17_tpu-8/checkpoint/checkpoint
# ssd_mobilenet_v2_fpnlite_320x320_coco17_tpu-8/checkpoint/ckpt-0.index
# ssd_mobilenet_v2_fpnlite_320x320_coco17_tpu-8/pipeline.config
# ssd_mobilenet_v2_fpnlite_320x320_coco17_tpu-8/saved_model/
# ssd_mobilenet_v2_fpnlite_320x320_coco17_tpu-8/saved_model/saved_model.pb
# ssd_mobilenet_v2_fpnlite_320x320_coco17_tpu-8/saved_model/variables/
# ssd_mobilenet_v2_fpnlite_320x320_coco17_tpu-8/saved_model/variables/variables.data-00000-of-00001
# ssd_mobilenet_v2_fpnlite_320x320_coco17_tpu-8/saved_model/variables/variables.index

# %% [markdown]
# # 2. Create Label Map

# %%
labels = [{'name':'license', 'id':1}]

with open(files['LABELMAP'], 'w') as f:
    for label in labels:
        f.write('item { \n')
        f.write('\tname:\'{}\'\n'.format(label['name']))
        f.write('\tid:{}\n'.format(label['id']))
        f.write('}\n')

# %% [markdown]
# # 3. Create TF records

# %%
train = os.mkdir('/content/Tensorflow/workspace/images/train')
test = os.mkdir('/content/Tensorflow/workspace/images/test')

# %%
import shutil
for n in range(1,801):
    c = str(n)+'.jpg'
    path = os.path.join('/content/drive/MyDrive/License Plate/Train/Detection/NewImages', c)
    shutil.copy(path, '/content/Tensorflow/workspace/images/train')
    a = str(n)+'.xml'
    patha = os.path.join('/content/drive/MyDrive/License Plate/Train/Detection/NewImages', a)
    shutil.copy(patha, '/content/Tensorflow/workspace/images/train')

# %%
for n in range(801, 901):
    c = str(n)+'.jpg'
    path = os.path.join('/content/drive/MyDrive/License Plate/Train/Detection/NewImages', c)
    shutil.copy(path, '/content/Tensorflow/workspace/images/test')
    a = str(n)+'.xml'
    patha = os.path.join('/content/drive/MyDrive/License Plate/Train/Detection/NewImages', a)
    shutil.copy(patha, '/content/Tensorflow/workspace/images/test')

# %%
# OPTIONAL IF RUNNING ON COLAB
ARCHIVE_FILES = os.path.join(paths['IMAGE_PATH'], 'archive.tar.gz')
if os.path.exists(ARCHIVE_FILES):
  # !tar -zxvf {ARCHIVE_FILES}

# %%
if not os.path.exists(files['TF_RECORD_SCRIPT']):
    # !git clone https://github.com/nicknochnack/GenerateTFRecord {paths['SCRIPTS_PATH']}
# Out:
# Cloning into 'Tensorflow/scripts'...
# remote: Enumerating objects: 3, done.
# remote: Counting objects: 100% (3/3), done.
# remote: Compressing objects: 100% (2/2), done.
# remote: Total 3 (delta 0), reused 1 (delta 0), pack-reused 0
# Unpacking objects: 100% (3/3), 2.67 KiB | 2.67 MiB/s, done.

# %%
# !python {files['TF_RECORD_SCRIPT']} -x {os.path.join(paths['IMAGE_PATH'], 'train')} -l {files['LABELMAP']} -o {os.path.join(paths['ANNOTATION_PATH'], 'train.record')} 
# !python {files['TF_RECORD_SCRIPT']} -x {os.path.join(paths['IMAGE_PATH'], 'test')} -l {files['LABELMAP']} -o {os.path.join(paths['ANNOTATION_PATH'], 'test.record')}
# Out:
# Successfully created the TFRecord file: Tensorflow/workspace/annotations/train.record
# Successfully created the TFRecord file: Tensorflow/workspace/annotations/test.record

# %% [markdown]
# # 4. Copy Model Config to Training Folder

# %%
if os.name =='posix':
    # !cp {os.path.join(paths['PRETRAINED_MODEL_PATH'], PRETRAINED_MODEL_NAME, 'pipeline.config')} {os.path.join(paths['CHECKPOINT_PATH'])}
if os.name == 'nt':
    # !copy {os.path.join(paths['PRETRAINED_MODEL_PATH'], PRETRAINED_MODEL_NAME, 'pipeline.config')} {os.path.join(paths['CHECKPOINT_PATH'])}

# %% [markdown]
# # 5. Update Config For Transfer Learning

# %%
import tensorflow as tf
from object_detection.utils import config_util
from object_detection.protos import pipeline_pb2
from google.protobuf import text_format

# %%
config = config_util.get_configs_from_pipeline_file(files['PIPELINE_CONFIG'])

# %%
config
# Out:
# {'model': ssd {
#    num_classes: 90
#    image_resizer {
#      fixed_shape_resizer {
#        height: 320
#        width: 320
#      }
#    }
#    feature_extractor {
#      type: "ssd_mobilenet_v2_fpn_keras"
#      depth_multiplier: 1.0
#      min_depth: 16
#      conv_hyperparams {
#        regularizer {
#          l2_regularizer {
#            weight: 3.9999998989515007e-05
#          }
#        }
#        initializer {
#          random_normal_initializer {
#            mean: 0.0
#            stddev: 0.009999999776482582
#          }
#        }
#        activation: RELU_6
#        batch_norm {
#          decay: 0.996999979019165
#          scale: true
#          epsilon: 0.0010000000474974513
#        }
#      }
#      use_depthwise: true
#      override_base_feature_extractor_hyperparams: true
#      fpn {
#        min_level: 3
#        max_level: 7
#        additional_layer_depth: 128
#      }
#    }
#    box_coder {
#      faster_rcnn_box_coder {
#        y_scale: 10.0
#        x_scale: 10.0
#        height_scale: 5.0
#        width_scale: 5.0
#      }
#    }
#    matcher {
#      argmax_matcher {
#        matched_threshold: 0.5
#        unmatched_threshold: 0.5
#        ignore_thresholds: false
#        negatives_lower_than_unmatched: true
#        force_match_for_each_row: true
#        use_matmul_gather: true
#      }
#    }
#    similarity_calculator {
#      iou_similarity {
#      }
#    }
#    box_predictor {
#      weight_shared_convolutional_box_predictor {
#        conv_hyperparams {
#          regularizer {
#            l2_regularizer {
#              weight: 3.9999998989515007e-05
#            }
#          }
#          initializer {
#            random_normal_initializer {
#              mean: 0.0
#              stddev: 0.009999999776482582
#            }
#          }
#          activation: RELU_6
#          batch_norm {
#            decay: 0.996999979019165
#            scale: true
#            epsilon: 0.0010000000474974513
#          }
#        }
#        depth: 128
#        num_layers_before_predictor: 4
#        kernel_size: 3
#        class_prediction_bias_init: -4.599999904632568
#        share_prediction_tower: true
#        use_depthwise: true
#      }
#    }
#    anchor_generator {
#      multiscale_anchor_generator {
#        min_level: 3
#        max_level: 7
#        anchor_scale: 4.0
#        aspect_ratios: 1.0
#        aspect_ratios: 2.0
#        aspect_ratios: 0.5
#        scales_per_octave: 2
#      }
#    }
#    post_processing {
#      batch_non_max_suppression {
#        score_threshold: 9.99999993922529e-09
#        iou_threshold: 0.6000000238418579
#        max_detections_per_class: 100
#        max_total_detections: 100
#        use_static_shapes: false
#      }
#      score_converter: SIGMOID
#    }
#    normalize_loss_by_num_matches: true
#    loss {
#      localization_loss {
#        weighted_smooth_l1 {
#        }
#      }
#      classification_loss {
#        weighted_sigmoid_focal {
#          gamma: 2.0
#          alpha: 0.25
#        }
#      }
#      classification_weight: 1.0
#      localization_weight: 1.0
#    }
#    encode_background_as_zeros: true
#    normalize_loc_loss_by_codesize: true
#    inplace_batchnorm_update: true
#    freeze_batchnorm: false
#  },
#  'train_config': batch_size: 128
#  data_augmentation_options {
#    random_horizontal_flip {
#    }
#  }
#  data_augmentation_options {
#    random_crop_image {
#      min_object_covered: 0.0
#      min_aspect_ratio: 0.75
#      max_aspect_ratio: 3.0
#      min_area: 0.75
#      max_area: 1.0
#      overlap_thresh: 0.0
#    }
#  }
#  sync_replicas: true
#  optimizer {
#    momentum_optimizer {
#      learning_rate {
#        cosine_decay_learning_rate {
#          learning_rate_base: 0.07999999821186066
#          total_steps: 50000
#          warmup_learning_rate: 0.026666000485420227
#          warmup_steps: 1000
#        }
#      }
#      momentum_optimizer_value: 0.8999999761581421
#    }
#    use_moving_average: false
#  }
#  fine_tune_checkpoint: "PATH_TO_BE_CONFIGURED"
#  num_steps: 50000
#  startup_delay_steps: 0.0
#  replicas_to_aggregate: 8
#  max_number_of_boxes: 100
#  unpad_groundtruth_tensors: false
#  fine_tune_checkpoint_type: "classification"
#  fine_tune_checkpoint_version: V2,
#  'train_input_config': label_map_path: "PATH_TO_BE_CONFIGURED"
#  tf_record_input_reader {
#    input_path: "PATH_TO_BE_CONFIGURED"
#  },
#  'eval_config': metrics_set: "coco_detection_metrics"
#  use_moving_averages: false,
#  'eval_input_configs': [label_map_path: "PATH_TO_BE_CONFIGURED"
#  shuffle: false
#  num_epochs: 1
#  tf_record_input_reader {
#    input_path: "PATH_TO_BE_CONFIGURED"
#  }
#  ],
#  'eval_input_config': label_map_path: "PATH_TO_BE_CONFIGURED"
#  shuffle: false
#  num_epochs: 1
#  tf_record_input_reader {
#    input_path: "PATH_TO_BE_CONFIGURED"
#  }}

# %%
pipeline_config = pipeline_pb2.TrainEvalPipelineConfig()
with tf.io.gfile.GFile(files['PIPELINE_CONFIG'], "r") as f:                                                                                                                                                                                                                     
    proto_str = f.read()                                                                                                                                                                                                                                          
    text_format.Merge(proto_str, pipeline_config)

# %%
pipeline_config.model.ssd.num_classes = len(labels)
pipeline_config.train_config.batch_size = 4
pipeline_config.train_config.fine_tune_checkpoint = os.path.join(paths['PRETRAINED_MODEL_PATH'], PRETRAINED_MODEL_NAME, 'checkpoint', 'ckpt-0')
pipeline_config.train_config.fine_tune_checkpoint_type = "detection"
pipeline_config.train_input_reader.label_map_path= files['LABELMAP']
pipeline_config.train_input_reader.tf_record_input_reader.input_path[:] = [os.path.join(paths['ANNOTATION_PATH'], 'train.record')]
pipeline_config.eval_input_reader[0].label_map_path = files['LABELMAP']
pipeline_config.eval_input_reader[0].tf_record_input_reader.input_path[:] = [os.path.join(paths['ANNOTATION_PATH'], 'test.record')]

# %%
config_text = text_format.MessageToString(pipeline_config)                                                                                                                                                                                                        
with tf.io.gfile.GFile(files['PIPELINE_CONFIG'], "wb") as f:                                                                                                                                                                                                                     
    f.write(config_text)

# %% [markdown]
# # 6. Train the model

# %%
TRAINING_SCRIPT = os.path.join(paths['APIMODEL_PATH'], 'research', 'object_detection', 'model_main_tf2.py')

# %%
command = "python {} --model_dir={} --pipeline_config_path={} --num_train_steps=50000".format(TRAINING_SCRIPT, paths['CHECKPOINT_PATH'],files['PIPELINE_CONFIG'])

# %%
print(command)
# Out:
# python Tensorflow/models/research/object_detection/model_main_tf2.py --model_dir=Tensorflow/workspace/models/my_ssd_mobnet --pipeline_config_path=Tensorflow/workspace/models/my_ssd_mobnet/pipeline.config --num_train_steps=50000

# %%
# !{command}
# Out:
# 2023-04-02 02:13:01.148705: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# /usr/local/lib/python3.9/dist-packages/tensorflow_addons/utils/ensure_tf_install.py:53: UserWarning: Tensorflow Addons supports using Python ops for all Tensorflow versions above or equal to 2.9.0 and strictly below 2.12.0 (nightly versions are not supported).
#  The versions of TensorFlow you are currently using is 2.12.0 and is not supported.
# Some things might work, some things might not.
# If you were to encounter a bug, do not file an issue.
# If you want to make sure you're using a tested and supported configuration, either change the TensorFlow version or the TensorFlow Addons's version.
# You can find the compatibility matrix in TensorFlow Addon's readme:
# https://github.com/tensorflow/addons
#   warnings.warn(
# 2023-04-02 02:13:05.567285: W tensorflow/core/common_runtime/gpu/gpu_bfc_allocator.cc:47] Overriding orig_value setting because the TF_FORCE_GPU_ALLOW_GROWTH environment variable is set. Original config value was 0.
# INFO:tensorflow:Using MirroredStrategy with devices ('/job:localhost/replica:0/task:0/device:GPU:0',)
# I0402 02:13:05.595636 139678128547648 mirrored_strategy.py:374] Using MirroredStrategy with devices ('/job:localhost/replica:0/task:0/device:GPU:0',)
# INFO:tensorflow:Maybe overwriting train_steps: 50000
# I0402 02:13:05.602000 139678128547648 config_util.py:552] Maybe overwriting train_steps: 50000
# INFO:tensorflow:Maybe overwriting use_bfloat16: False
# I0402 02:13:05.602286 139678128547648 config_util.py:552] Maybe overwriting use_bfloat16: False
# WARNING:tensorflow:From /usr/local/lib/python3.9/dist-packages/object_detection/model_lib_v2.py:563: StrategyBase.experimental_distribute_datasets_from_function (from tensorflow.python.distribute.distribute_lib) is deprecated and will be removed in a future version.
# Instructions for updating:
# rename to distribute_datasets_from_function
# W0402 02:13:05.643671 139678128547648 deprecation.py:364] From /usr/local/lib/python3.9/dist-packages/object_detection/model_lib_v2.py:563: StrategyBase.experimental_distribute_datasets_from_function (from tensorflow.python.distribute.distribute_lib) is deprecated and will be removed in a future version.
# Instructions for updating:
# rename to distribute_datasets_from_function
# INFO:tensorflow:Reading unweighted datasets: ['Tensorflow/workspace/annotations/train.record']
# I0402 02:13:05.653575 139678128547648 dataset_builder.py:162] Reading unweighted datasets: ['Tensorflow/workspace/annotations/train.record']
# INFO:tensorflow:Reading record datasets for input file: ['Tensorflow/workspace/annotations/train.record']
# I0402 02:13:05.653808 139678128547648 dataset_builder.py:79] Reading record datasets for input file: ['Tensorflow/workspace/annotations/train.record']
# INFO:tensorflow:Number of filenames to read: 1
# I0402 02:13:05.653925 139678128547648 dataset_builder.py:80] Number of filenames to read: 1
# WARNING:tensorflow:num_readers has been reduced to 1 to match input file shards.
# W0402 02:13:05.654003 139678128547648 dataset_builder.py:86] num_readers has been reduced to 1 to match input file shards.
# WARNING:tensorflow:From /usr/local/lib/python3.9/dist-packages/object_detection/builders/dataset_builder.py:100: parallel_interleave (from tensorflow.python.data.experimental.ops.interleave_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.data.Dataset.interleave(map_func, cycle_length, block_length, num_parallel_calls=tf.data.AUTOTUNE)` instead. If sloppy execution is desired, use `tf.data.Options.deterministic`.
# W0402 02:13:05.664423 139678128547648 deprecation.py:364] From /usr/local/lib/python3.9/dist-packages/object_detection/builders/dataset_builder.py:100: parallel_interleave (from tensorflow.python.data.experimental.ops.interleave_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.data.Dataset.interleave(map_func, cycle_length, block_length, num_parallel_calls=tf.data.AUTOTUNE)` instead. If sloppy execution is desired, use `tf.data.Options.deterministic`.
# WARNING:tensorflow:From /usr/local/lib/python3.9/dist-packages/object_detection/builders/dataset_builder.py:235: DatasetV1.map_with_legacy_function (from tensorflow.python.data.ops.dataset_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.data.Dataset.map()
# W0402 02:13:05.689778 139678128547648 deprecation.py:364] From /usr/local/lib/python3.9/dist-packages/object_detection/builders/dataset_builder.py:235: DatasetV1.map_with_legacy_function (from tensorflow.python.data.ops.dataset_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.data.Dataset.map()
# WARNING:tensorflow:From /usr/local/lib/python3.9/dist-packages/tensorflow/python/util/dispatch.py:1176: sparse_to_dense (from tensorflow.python.ops.sparse_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Create a `tf.sparse.SparseTensor` and use `tf.sparse.to_dense` instead.
# W0402 02:13:14.687998 139678128547648 deprecation.py:364] From /usr/local/lib/python3.9/dist-packages/tensorflow/python/util/dispatch.py:1176: sparse_to_dense (from tensorflow.python.ops.sparse_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Create a `tf.sparse.SparseTensor` and use `tf.sparse.to_dense` instead.
# WARNING:tensorflow:From /usr/local/lib/python3.9/dist-packages/tensorflow/python/util/dispatch.py:1176: sample_distorted_bounding_box (from tensorflow.python.ops.image_ops_impl) is deprecated and will be removed in a future version.
# Instructions for updating:
# `seed2` arg is deprecated.Use sample_distorted_bounding_box_v2 instead.
# W0402 02:13:17.384517 139678128547648 deprecation.py:364] From /usr/local/lib/python3.9/dist-packages/tensorflow/python/util/dispatch.py:1176: sample_distorted_bounding_box (from tensorflow.python.ops.image_ops_impl) is deprecated and will be removed in a future version.
# Instructions for updating:
# `seed2` arg is deprecated.Use sample_distorted_bounding_box_v2 instead.
# WARNING:tensorflow:From /usr/local/lib/python3.9/dist-packages/tensorflow/python/util/dispatch.py:1176: to_float (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.cast` instead.
# W0402 02:13:18.897981 139678128547648 deprecation.py:364] From /usr/local/lib/python3.9/dist-packages/tensorflow/python/util/dispatch.py:1176: to_float (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.cast` instead.
# WARNING:tensorflow:From /usr/local/lib/python3.9/dist-packages/object_detection/builders/optimizer_builder.py:124: The name tf.keras.optimizers.SGD is deprecated. Please use tf.keras.optimizers.legacy.SGD instead.
#
# W0402 02:13:21.104950 139678128547648 module_wrapper.py:149] From /usr/local/lib/python3.9/dist-packages/object_detection/builders/optimizer_builder.py:124: The name tf.keras.optimizers.SGD is deprecated. Please use tf.keras.optimizers.legacy.SGD instead.
#
# /usr/local/lib/python3.9/dist-packages/keras/backend.py:452: UserWarning: `tf.keras.backend.set_learning_phase` is deprecated and will be removed after 2020-10-11. To update it, simply pass a True/False value to the `training` argument of the `__call__` method of your layer or model.
#   warnings.warn(
# I0402 02:13:28.714030 139673200809728 api.py:459] feature_map_spatial_dims: [(40, 40), (20, 20), (10, 10), (5, 5), (3, 3)]
# I0402 02:13:37.232921 139673200809728 api.py:459] feature_map_spatial_dims: [(40, 40), (20, 20), (10, 10), (5, 5), (3, 3)]
# WARNING:tensorflow:From /usr/local/lib/python3.9/dist-packages/tensorflow/python/util/deprecation.py:648: calling map_fn_v2 (from tensorflow.python.ops.map_fn) with dtype is deprecated and will be removed in a future version.
# Instructions for updating:
# Use fn_output_signature instead
# W0402 02:13:49.691069 139673292756736 deprecation.py:569] From /usr/local/lib/python3.9/dist-packages/tensorflow/python/util/deprecation.py:648: calling map_fn_v2 (from tensorflow.python.ops.map_fn) with dtype is deprecated and will be removed in a future version.
# Instructions for updating:
# Use fn_output_signature instead
# I0402 02:13:51.365298 139673292756736 api.py:459] feature_map_spatial_dims: [(40, 40), (20, 20), (10, 10), (5, 5), (3, 3)]
# I0402 02:13:57.445106 139673292756736 api.py:459] feature_map_spatial_dims: [(40, 40), (20, 20), (10, 10), (5, 5), (3, 3)]
# I0402 02:14:02.399200 139673292756736 api.py:459] feature_map_spatial_dims: [(40, 40), (20, 20), (10, 10), (5, 5), (3, 3)]
# I0402 02:14:08.704585 139673292756736 api.py:459] feature_map_spatial_dims: [(40, 40), (20, 20), (10, 10), (5, 5), (3, 3)]
# INFO:tensorflow:Step 20100 per-step time 0.417s
# I0402 02:14:30.462145 139678128547648 model_lib_v2.py:705] Step 20100 per-step time 0.417s
# INFO:tensorflow:{'Loss/classification_loss': 0.04268961,
#  'Loss/localization_loss': 0.02231837,
#  'Loss/regularization_loss': 0.08928141,
#  'Loss/total_loss': 0.1542894,
#  'learning_rate': 0.053573642}
# I0402 02:14:30.462525 139678128547648 model_lib_v2.py:708] {'Loss/classification_loss': 0.04268961,
#  'Loss/localization_loss': 0.02231837,
#  'Loss/regularization_loss': 0.08928141,
#  'Loss/total_loss': 0.1542894,
#  'learning_rate': 0.053573642}
# INFO:tensorflow:Step 20200 per-step time 0.066s
# I0402 02:14:36.995605 139678128547648 model_lib_v2.py:705] Step 20200 per-step time 0.066s
# INFO:tensorflow:{'Loss/classification_loss': 0.08490337,
#  'Loss/localization_loss': 0.06254753,
#  'Loss/regularization_loss': 0.08904997,
#  'Loss/total_loss': 0.23650086,
#  'learning_rate': 0.053332124}
# I0402 02:14:36.995926 139678128547648 model_lib_v2.py:708] {'Loss/classification_loss': 0.08490337,
#  'Loss/localization_loss': 0.06254753,
#  'Loss/regularization_loss': 0.08904997,
#  'Loss/total_loss': 0.23650086,
#  'learning_rate': 0.053332124}
# INFO:tensorflow:Step 20300 per-step time 0.059s
# I0402 02:14:42.935627 139678128547648 model_lib_v2.py:705] Step 20300 per-step time 0.059s
# INFO:tensorflow:{'Loss/classification_loss': 0.15165298,
#  'Loss/localization_loss': 0.06333759,
#  'Loss/regularization_loss': 0.08880504,
#  'Loss/total_loss': 0.3037956,
#  'learning_rate': 0.053090062}
# I0402 02:14:42.936043 139678128547648 model_lib_v2.py:708] {'Loss/classification_loss': 0.15165298,
#  'Loss/localization_loss': 0.06333759,
#  'Loss/regularization_loss': 0.08880504,
#  'Loss/total_loss': 0.3037956,
#  'learning_rate': 0.053090062}
# INFO:tensorflow:Step 20400 per-step time 0.083s
# I0402 02:14:51.259645 139678128547648 model_lib_v2.py:705] Step 20400 per-step time 0.083s
# INFO:tensorflow:{'Loss/classification_loss': 0.121249475,
#  'Loss/localization_loss': 0.09048234,
#  'Loss/regularization_loss': 0.08854724,
#  'Loss/total_loss': 0.30027905,
#  'learning_rate': 0.05284746}
# I0402 02:14:51.260056 139678128547648 model_lib_v2.py:708] {'Loss/classification_loss': 0.121249475,
#  'Loss/localization_loss': 0.09048234,
#  'Loss/regularization_loss': 0.08854724,
#  'Loss/total_loss': 0.30027905,
#  'learning_rate': 0.05284746}
# INFO:tensorflow:Step 20500 per-step time 0.062s
# I0402 02:14:57.453607 139678128547648 model_lib_v2.py:705] Step 20500 per-step time 0.062s
# INFO:tensorflow:{'Loss/classification_loss': 0.05470256,
#  'Loss/localization_loss': 0.06987671,
#  'Loss/regularization_loss': 0.08826642,
#  'Loss/total_loss': 0.21284568,
#  'learning_rate': 0.052604325}
# I0402 02:14:57.453913 139678128547648 model_lib_v2.py:708] {'Loss/classification_loss': 0.05470256,
#  'Loss/localization_loss': 0.06987671,
#  'Loss/regularization_loss': 0.08826642,
#  'Loss/total_loss': 0.21284568,
#  'learning_rate': 0.052604325}
# INFO:tensorflow:Step 20600 per-step time 0.063s
# I0402 02:15:03.782944 139678128547648 model_lib_v2.py:705] Step 20600 per-step time 0.063s
# INFO:tensorflow:{'Loss/classification_loss': 0.14554127,
#  'Loss/localization_loss': 0.053447522,
#  'Loss/regularization_loss': 0.08799684,
#  'Loss/total_loss': 0.28698564,
#  'learning_rate': 0.052360676}
# I0402 02:15:03.783285 139678128547648 model_lib_v2.py:708] {'Loss/classification_loss': 0.14554127,
#  'Loss/localization_loss': 0.053447522,
#  'Loss/regularization_loss': 0.08799684,
#  'Loss/total_loss': 0.28698564,
#  'learning_rate': 0.052360676}
# INFO:tensorflow:Step 20700 per-step time 0.081s
# I0402 02:15:11.930423 139678128547648 model_lib_v2.py:705] Step 20700 per-step time 0.081s
# INFO:tensorflow:{'Loss/classification_loss': 0.09491707,
#  'Loss/localization_loss': 0.017594114,
#  'Loss/regularization_loss': 0.08772315,
#  'Loss/total_loss': 0.20023432,
#  'learning_rate': 0.05211652}
# I0402 02:15:11.930713 139678128547648 model_lib_v2.py:708] {'Loss/classification_loss': 0.09491707,
#  'Loss/localization_loss': 0.017594114,
#  'Loss/regularization_loss': 0.08772315,
#  'Loss/total_loss': 0.20023432,
#  'learning_rate': 0.05211652}
# INFO:tensorflow:Step 20800 per-step time 0.060s
# I0402 02:15:17.919987 139678128547648 model_lib_v2.py:705] Step 20800 per-step time 0.060s
# INFO:tensorflow:{'Loss/classification_loss': 0.13489248,
#  'Loss/localization_loss': 0.03563633,
#  'Loss/regularization_loss': 0.087540016,
#  'Loss/total_loss': 0.2580688,
#  'learning_rate': 0.05187187}
# I0402 02:15:17.920300 139678128547648 model_lib_v2.py:708] {'Loss/classification_loss': 0.13489248,
#  'Loss/localization_loss': 0.03563633,
#  'Loss/regularization_loss': 0.087540016,
#  'Loss/total_loss': 0.2580688,
#  'learning_rate': 0.05187187}
# INFO:tensorflow:Step 20900 per-step time 0.068s
# I0402 02:15:24.760119 139678128547648 model_lib_v2.py:705] Step 20900 per-step time 0.068s
# INFO:tensorflow:{'Loss/classification_loss': 0.12019116,
#  'Loss/localization_loss': 0.09619939,
#  'Loss/regularization_loss': 0.08730653,
#  'Loss/total_loss': 0.30369708,
#  'learning_rate': 0.051626723}
# I0402 02:15:24.760469 139678128547648 model_lib_v2.py:708] {'Loss/classification_loss': 0.12019116,
#  'Loss/localization_loss': 0.09619939,
#  'Loss/regularization_loss': 0.08730653,
#  'Loss/total_loss': 0.30369708,
#  'learning_rate': 0.051626723}
# INFO:tensorflow:Step 21000 per-step time 0.080s
# I0402 02:15:32.718712 139678128547648 model_lib_v2.py:705] Step 21000 per-step time 0.080s
# INFO:tensorflow:{'Loss/classification_loss': 0.087168396,
#  'Loss/localization_loss': 0.04120646,
#  'Loss/regularization_loss': 0.08706955,
#  'Loss/total_loss': 0.21544442,
#  'learning_rate': 0.0513811}
# I0402 02:15:32.719017 139678128547648 model_lib_v2.py:708] {'Loss/classification_loss': 0.087168396,
#  'Loss/localization_loss': 0.04120646,
#  'Loss/regularization_loss': 0.08706955,
#  'Loss/total_loss': 0.21544442,
#  'learning_rate': 0.0513811}
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# I0402 02:15:32.813698 139678128547648 cross_device_ops.py:616] Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# I0402 02:15:32.815833 139678128547648 cross_device_ops.py:616] Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# I0402 02:15:32.816943 139678128547648 cross_device_ops.py:616] Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# I0402 02:15:32.817888 139678128547648 cross_device_ops.py:616] Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# I0402 02:15:32.821520 139678128547648 cross_device_ops.py:616] Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# I0402 02:15:32.822589 139678128547648 cross_device_ops.py:616] Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# I0402 02:15:32.823700 139678128547648 cross_device_ops.py:616] Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# I0402 02:15:32.824644 139678128547648 cross_device_ops.py:616] Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# I0402 02:15:32.829108 139678128547648 cross_device_ops.py:616] Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# I0402 02:15:32.830128 139678128547648 cross_device_ops.py:616] Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# INFO:tensorflow:Step 21100 per-step time 0.074s
# I0402 02:15:40.123757 139678128547648 model_lib_v2.py:705] Step 21100 per-step time 0.074s
# INFO:tensorflow:{'Loss/classification_loss': 0.10037173,
#  'Loss/localization_loss': 0.036236167,
#  'Loss/regularization_loss': 0.086813666,
#  'Loss/total_loss': 0.22342157,
#  'learning_rate': 0.051135015}
# I0402 02:15:40.124106 139678128547648 model_lib_v2.py:708] {'Loss/classification_loss': 0.10037173,
#  'Loss/localization_loss': 0.036236167,
#  'Loss/regularization_loss': 0.086813666,
#  'Loss/total_loss': 0.22342157,
#  'learning_rate': 0.051135015}
# INFO:tensorflow:Step 21200 per-step time 0.084s
# I0402 02:15:48.529791 139678128547648 model_lib_v2.py:705] Step 21200 per-step time 0.084s
# INFO:tensorflow:{'Loss/classification_loss': 0.061126336,
#  'Loss/localization_loss': 0.019012019,
#  'Loss/regularization_loss': 0.0865685,
#  'Loss/total_loss': 0.16670686,
#  'learning_rate': 0.050888464}
# I0402 02:15:48.530173 139678128547648 model_lib_v2.py:708] {'Loss/classification_loss': 0.061126336,
#  'Loss/localization_loss': 0.019012019,
#  'Loss/regularization_loss': 0.0865685,
#  'Loss/total_loss': 0.16670686,
#  'learning_rate': 0.050888464}
# INFO:tensorflow:Step 21300 per-step time 0.091s
# I0402 02:15:57.634456 139678128547648 model_lib_v2.py:705] Step 21300 per-step time 0.091s
# INFO:tensorflow:{'Loss/classification_loss': 0.09545901,
#  'Loss/localization_loss': 0.06187296,
#  'Loss/regularization_loss': 0.08645182,
#  'Loss/total_loss': 0.2437838,
#  'learning_rate': 0.05064147}
# I0402 02:15:57.634846 139678128547648 model_lib_v2.py:708] {'Loss/classification_loss': 0.09545901,
#  'Loss/localization_loss': 0.06187296,
#  'Loss/regularization_loss': 0.08645182,
#  'Loss/total_loss': 0.2437838,
#  'learning_rate': 0.05064147}
# INFO:tensorflow:Step 21400 per-step time 0.063s
# I0402 02:16:03.912436 139678128547648 model_lib_v2.py:705] Step 21400 per-step time 0.063s
# INFO:tensorflow:{'Loss/classification_loss': 0.12562138,
#  'Loss/localization_loss': 0.07361775,
#  'Loss/regularization_loss': 0.08688943,
#  'Loss/total_loss': 0.28612858,
#  'learning_rate': 0.05039404}
# I0402 02:16:03.912757 139678128547648 model_lib_v2.py:708] {'Loss/classification_loss': 0.12562138,
#  'Loss/localization_loss': 0.07361775,
#  'Loss/regularization_loss': 0.08688943,
#  'Loss/total_loss': 0.28612858,
#  'learning_rate': 0.05039404}
# INFO:tensorflow:Step 21500 per-step time 0.071s
# I0402 02:16:11.035212 139678128547648 model_lib_v2.py:705] Step 21500 per-step time 0.071s
# INFO:tensorflow:{'Loss/classification_loss': 0.09501924,
#  'Loss/localization_loss': 0.088565506,
#  'Loss/regularization_loss': 0.08666794,
#  'Loss/total_loss': 0.2702527,
#  'learning_rate': 0.050146177}
# I0402 02:16:11.035604 139678128547648 model_lib_v2.py:708] {'Loss/classification_loss': 0.09501924,
#  'Loss/localization_loss': 0.088565506,
#  'Loss/regularization_loss': 0.08666794,
#  'Loss/total_loss': 0.2702527,
#  'learning_rate': 0.050146177}
# INFO:tensorflow:Step 21600 per-step time 0.078s
# I0402 02:16:18.851843 139678128547648 model_lib_v2.py:705] Step 21600 per-step time 0.078s
# INFO:tensorflow:{'Loss/classification_loss': 0.06232565,
#  'Loss/localization_loss': 0.05135555,
#  'Loss/regularization_loss': 0.08647233,
#  'Loss/total_loss': 0.20015353,
#  'learning_rate': 0.04989791}
# I0402 02:16:18.852157 139678128547648 model_lib_v2.py:708] {'Loss/classification_loss': 0.06232565,
#  'Loss/localization_loss': 0.05135555,
#  'Loss/regularization_loss': 0.08647233,
#  'Loss/total_loss': 0.20015353,
#  'learning_rate': 0.04989791}
# INFO:tensorflow:Step 21700 per-step time 0.059s
# I0402 02:16:24.761180 139678128547648 model_lib_v2.py:705] Step 21700 per-step time 0.059s
# INFO:tensorflow:{'Loss/classification_loss': 0.060234696,
#  'Loss/localization_loss': 0.03967172,
#  'Loss/regularization_loss': 0.08628917,
#  'Loss/total_loss': 0.18619558,
#  'learning_rate': 0.049649224}
# I0402 02:16:24.761517 139678128547648 model_lib_v2.py:708] {'Loss/classification_loss': 0.060234696,
#  'Loss/localization_loss': 0.03967172,
#  'Loss/regularization_loss': 0.08628917,
#  'Loss/total_loss': 0.18619558,
#  'learning_rate': 0.049649224}
# INFO:tensorflow:Step 21800 per-step time 0.077s
# I0402 02:16:32.418880 139678128547648 model_lib_v2.py:705] Step 21800 per-step time 0.077s
# INFO:tensorflow:{'Loss/classification_loss': 0.061414044,
#  'Loss/localization_loss': 0.019700734,
#  'Loss/regularization_loss': 0.08605557,
#  'Loss/total_loss': 0.16717035,
#  'learning_rate': 0.049400143}
# I0402 02:16:32.419236 139678128547648 model_lib_v2.py:708] {'Loss/classification_loss': 0.061414044,
#  'Loss/localization_loss': 0.019700734,
#  'Loss/regularization_loss': 0.08605557,
#  'Loss/total_loss': 0.16717035,
#  'learning_rate': 0.049400143}
# INFO:tensorflow:Step 21900 per-step time 0.074s
# I0402 02:16:39.775875 139678128547648 model_lib_v2.py:705] Step 21900 per-step time 0.074s
# INFO:tensorflow:{'Loss/classification_loss': 0.060902644,
#  'Loss/localization_loss': 0.041294612,
#  'Loss/regularization_loss': 0.085834436,
#  'Loss/total_loss': 0.1880317,
#  'learning_rate': 0.049150676}
# I0402 02:16:39.776199 139678128547648 model_lib_v2.py:708] {'Loss/classification_loss': 0.060902644,
#  'Loss/localization_loss': 0.041294612,
#  'Loss/regularization_loss': 0.085834436,
#  'Loss/total_loss': 0.1880317,
#  'learning_rate': 0.049150676}
# INFO:tensorflow:Step 22000 per-step time 0.059s
# I0402 02:16:45.696818 139678128547648 model_lib_v2.py:705] Step 22000 per-step time 0.059s
# INFO:tensorflow:{'Loss/classification_loss': 0.10306207,
#  'Loss/localization_loss': 0.069477625,
#  'Loss/regularization_loss': 0.08560168,
#  'Loss/total_loss': 0.25814137,
#  'learning_rate': 0.048900835}
# I0402 02:16:45.697161 139678128547648 model_lib_v2.py:708] {'Loss/classification_loss': 0.10306207,
#  'Loss/localization_loss': 0.069477625,
#  'Loss/regularization_loss': 0.08560168,
#  'Loss/total_loss': 0.25814137,
#  'learning_rate': 0.048900835}
# INFO:tensorflow:Step 22100 per-step time 0.101s
# I0402 02:16:55.771595 139678128547648 model_lib_v2.py:705] Step 22100 per-step time 0.101s
# INFO:tensorflow:{'Loss/classification_loss': 0.07474978,
#  'Loss/localization_loss': 0.05911212,
#  'Loss/regularization_loss': 0.08535241,
#  'Loss/total_loss': 0.21921432,
#  'learning_rate': 0.048650626}
# I0402 02:16:55.771987 139678128547648 model_lib_v2.py:708] {'Loss/classification_loss': 0.07474978,
#  'Loss/localization_loss': 0.05911212,
#  'Loss/regularization_loss': 0.08535241,
#  'Loss/total_loss': 0.21921432,
#  'learning_rate': 0.048650626}
# INFO:tensorflow:Step 22200 per-step time 0.063s
# I0402 02:17:02.055375 139678128547648 model_lib_v2.py:705] Step 22200 per-step time 0.063s
# INFO:tensorflow:{'Loss/classification_loss': 0.17549938,
#  'Loss/localization_loss': 0.032249425,
#  'Loss/regularization_loss': 0.08512808,
#  'Loss/total_loss': 0.29287687,
#  'learning_rate': 0.048400067}
# I0402 02:17:02.055669 139678128547648 model_lib_v2.py:708] {'Loss/classification_loss': 0.17549938,
#  'Loss/localization_loss': 0.032249425,
#  'Loss/regularization_loss': 0.08512808,
#  'Loss/total_loss': 0.29287687,
#  'learning_rate': 0.048400067}
# INFO:tensorflow:Step 22300 per-step time 0.065s
# I0402 02:17:08.572442 139678128547648 model_lib_v2.py:705] Step 22300 per-step time 0.065s
# INFO:tensorflow:{'Loss/classification_loss': 0.119767234,
#  'Loss/localization_loss': 0.040962394,
#  'Loss/regularization_loss': 0.08491435,
#  'Loss/total_loss': 0.24564397,
#  'learning_rate': 0.048149157}
# I0402 02:17:08.572789 139678128547648 model_lib_v2.py:708] {'Loss/classification_loss': 0.119767234,
#  'Loss/localization_loss': 0.040962394,
#  'Loss/regularization_loss': 0.08491435,
#  'Loss/total_loss': 0.24564397,
#  'learning_rate': 0.048149157}
# INFO:tensorflow:Step 22400 per-step time 0.084s
# I0402 02:17:16.930523 139678128547648 model_lib_v2.py:705] Step 22400 per-step time 0.084s
# INFO:tensorflow:{'Loss/classification_loss': 0.21007553,
#  'Loss/localization_loss': 0.06122758,
#  'Loss/regularization_loss': 0.08467772,
#  'Loss/total_loss': 0.35598084,
#  'learning_rate': 0.04789791}
# I0402 02:17:16.930848 139678128547648 model_lib_v2.py:708] {'Loss/classification_loss': 0.21007553,
#  'Loss/localization_loss': 0.06122758,
#  'Loss/regularization_loss': 0.08467772,
#  'Loss/total_loss': 0.35598084,
#  'learning_rate': 0.04789791}
# INFO:tensorflow:Step 22500 per-step time 0.060s
# I0402 02:17:22.957312 139678128547648 model_lib_v2.py:705] Step 22500 per-step time 0.060s
# INFO:tensorflow:{'Loss/classification_loss': 0.10403022,
#  'Loss/localization_loss': 0.024621788,
#  'Loss/regularization_loss': 0.084478185,
#  'Loss/total_loss': 0.21313019,
#  'learning_rate': 0.04764634}
# I0402 02:17:22.957615 139678128547648 model_lib_v2.py:708] {'Loss/classification_loss': 0.10403022,
#  'Loss/localization_loss': 0.024621788,
#  'Loss/regularization_loss': 0.084478185,
#  'Loss/total_loss': 0.21313019,
#  'learning_rate': 0.04764634}
# INFO:tensorflow:Step 22600 per-step time 0.069s
# I0402 02:17:29.895930 139678128547648 model_lib_v2.py:705] Step 22600 per-step time 0.069s
# INFO:tensorflow:{'Loss/classification_loss': 0.1338917,
#  'Loss/localization_loss': 0.043371707,
#  'Loss/regularization_loss': 0.084319666,
#  'Loss/total_loss': 0.2615831,
#  'learning_rate': 0.047394462}
# I0402 02:17:29.896585 139678128547648 model_lib_v2.py:708] {'Loss/classification_loss': 0.1338917,
#  'Loss/localization_loss': 0.043371707,
#  'Loss/regularization_loss': 0.084319666,
#  'Loss/total_loss': 0.2615831,
#  'learning_rate': 0.047394462}
# INFO:tensorflow:Step 22700 per-step time 0.078s
# I0402 02:17:37.657509 139678128547648 model_lib_v2.py:705] Step 22700 per-step time 0.078s
# INFO:tensorflow:{'Loss/classification_loss': 0.08061027,
#  'Loss/localization_loss': 0.018756693,
#  'Loss/regularization_loss': 0.0840826,
#  'Loss/total_loss': 0.18344957,
#  'learning_rate': 0.04714227}
# I0402 02:17:37.657815 139678128547648 model_lib_v2.py:708] {'Loss/classification_loss': 0.08061027,
#  'Loss/localization_loss': 0.018756693,
#  'Loss/regularization_loss': 0.0840826,
#  'Loss/total_loss': 0.18344957,
#  'learning_rate': 0.04714227}
# INFO:tensorflow:Step 22800 per-step time 0.060s
# I0402 02:17:43.647299 139678128547648 model_lib_v2.py:705] Step 22800 per-step time 0.060s
# INFO:tensorflow:{'Loss/classification_loss': 0.09888266,
#  'Loss/localization_loss': 0.068505555,
#  'Loss/regularization_loss': 0.08388612,
#  'Loss/total_loss': 0.25127435,
#  'learning_rate': 0.046889797}
# I0402 02:17:43.647588 139678128547648 model_lib_v2.py:708] {'Loss/classification_loss': 0.09888266,
#  'Loss/localization_loss': 0.068505555,
#  'Loss/regularization_loss': 0.08388612,
#  'Loss/total_loss': 0.25127435,
#  'learning_rate': 0.046889797}
# INFO:tensorflow:Step 22900 per-step time 0.076s
# I0402 02:17:51.248237 139678128547648 model_lib_v2.py:705] Step 22900 per-step time 0.076s
# INFO:tensorflow:{'Loss/classification_loss': 0.100951985,
#  'Loss/localization_loss': 0.029714052,
#  'Loss/regularization_loss': 0.08366313,
#  'Loss/total_loss': 0.21432915,
#  'learning_rate': 0.046637025}
# I0402 02:17:51.254167 139678128547648 model_lib_v2.py:708] {'Loss/classification_loss': 0.100951985,
#  'Loss/localization_loss': 0.029714052,
#  'Loss/regularization_loss': 0.08366313,
#  'Loss/total_loss': 0.21432915,
#  'learning_rate': 0.046637025}
# INFO:tensorflow:Step 23000 per-step time 0.094s
# I0402 02:18:00.606200 139678128547648 model_lib_v2.py:705] Step 23000 per-step time 0.094s
# INFO:tensorflow:{'Loss/classification_loss': 0.11330557,
#  'Loss/localization_loss': 0.05014201,
#  'Loss/regularization_loss': 0.08344888,
#  'Loss/total_loss': 0.24689645,
#  'learning_rate': 0.046383996}
# I0402 02:18:00.606565 139678128547648 model_lib_v2.py:708] {'Loss/classification_loss': 0.11330557,
#  'Loss/localization_loss': 0.05014201,
#  'Loss/regularization_loss': 0.08344888,
#  'Loss/total_loss': 0.24689645,
#  'learning_rate': 0.046383996}
# INFO:tensorflow:Step 23100 per-step time 0.082s
# I0402 02:18:08.807082 139678128547648 model_lib_v2.py:705] Step 23100 per-step time 0.082s
# INFO:tensorflow:{'Loss/classification_loss': 0.07519356,
#  'Loss/localization_loss': 0.01381141,
#  'Loss/regularization_loss': 0.08322695,
#  'Loss/total_loss': 0.17223191,
#  'learning_rate': 0.04613069}
# I0402 02:18:08.807421 139678128547648 model_lib_v2.py:708] {'Loss/classification_loss': 0.07519356,
#  'Loss/localization_loss': 0.01381141,
#  'Loss/regularization_loss': 0.08322695,
#  'Loss/total_loss': 0.17223191,
#  'learning_rate': 0.04613069}
# INFO:tensorflow:Step 23200 per-step time 0.073s
# I0402 02:18:16.145012 139678128547648 model_lib_v2.py:705] Step 23200 per-step time 0.073s
# INFO:tensorflow:{'Loss/classification_loss': 0.10926752,
#  'Loss/localization_loss': 0.034531172,
#  'Loss/regularization_loss': 0.08298965,
#  'Loss/total_loss': 0.22678834,
#  'learning_rate': 0.04587714}
# I0402 02:18:16.145390 139678128547648 model_lib_v2.py:708] {'Loss/classification_loss': 0.10926752,
#  'Loss/localization_loss': 0.034531172,
#  'Loss/regularization_loss': 0.08298965,
#  'Loss/total_loss': 0.22678834,
#  'learning_rate': 0.04587714}
# INFO:tensorflow:Step 23300 per-step time 0.076s
# I0402 02:18:23.697210 139678128547648 model_lib_v2.py:705] Step 23300 per-step time 0.076s
# INFO:tensorflow:{'Loss/classification_loss': 0.120463155,
#  'Loss/localization_loss': 0.032433495,
#  'Loss/regularization_loss': 0.08276931,
#  'Loss/total_loss': 0.23566595,
#  'learning_rate': 0.045623355}
# I0402 02:18:23.697508 139678128547648 model_lib_v2.py:708] {'Loss/classification_loss': 0.120463155,
#  'Loss/localization_loss': 0.032433495,
#  'Loss/regularization_loss': 0.08276931,
#  'Loss/total_loss': 0.23566595,
#  'learning_rate': 0.045623355}
# INFO:tensorflow:Step 23400 per-step time 0.061s
# I0402 02:18:29.791383 139678128547648 model_lib_v2.py:705] Step 23400 per-step time 0.061s
# INFO:tensorflow:{'Loss/classification_loss': 0.09813164,
#  'Loss/localization_loss': 0.035101734,
#  'Loss/regularization_loss': 0.08254967,
#  'Loss/total_loss': 0.21578303,
#  'learning_rate': 0.045369323}
# I0402 02:18:29.791678 139678128547648 model_lib_v2.py:708] {'Loss/classification_loss': 0.09813164,
#  'Loss/localization_loss': 0.035101734,
#  'Loss/regularization_loss': 0.08254967,
#  'Loss/total_loss': 0.21578303,
#  'learning_rate': 0.045369323}
# INFO:tensorflow:Step 23500 per-step time 0.079s
# I0402 02:18:37.654005 139678128547648 model_lib_v2.py:705] Step 23500 per-step time 0.079s
# INFO:tensorflow:{'Loss/classification_loss': 0.14342695,
#  'Loss/localization_loss': 0.020992447,
#  'Loss/regularization_loss': 0.08238649,
#  'Loss/total_loss': 0.24680589,
#  'learning_rate': 0.045115083}
# I0402 02:18:37.654428 139678128547648 model_lib_v2.py:708] {'Loss/classification_loss': 0.14342695,
#  'Loss/localization_loss': 0.020992447,
#  'Loss/regularization_loss': 0.08238649,
#  'Loss/total_loss': 0.24680589,
#  'learning_rate': 0.045115083}
# INFO:tensorflow:Step 23600 per-step time 0.071s
# I0402 02:18:44.749019 139678128547648 model_lib_v2.py:705] Step 23600 per-step time 0.071s
# INFO:tensorflow:{'Loss/classification_loss': 0.08587393,
#  'Loss/localization_loss': 0.04682885,
#  'Loss/regularization_loss': 0.08216588,
#  'Loss/total_loss': 0.21486866,
#  'learning_rate': 0.044860635}
# I0402 02:18:44.749317 139678128547648 model_lib_v2.py:708] {'Loss/classification_loss': 0.08587393,
#  'Loss/localization_loss': 0.04682885,
#  'Loss/regularization_loss': 0.08216588,
#  'Loss/total_loss': 0.21486866,
#  'learning_rate': 0.044860635}
# INFO:tensorflow:Step 23700 per-step time 0.061s
# I0402 02:18:50.813268 139678128547648 model_lib_v2.py:705] Step 23700 per-step time 0.061s
# INFO:tensorflow:{'Loss/classification_loss': 0.4912954,
#  'Loss/localization_loss': 0.112246335,
#  'Loss/regularization_loss': 0.081970185,
#  'Loss/total_loss': 0.68551195,
#  'learning_rate': 0.044605974}
# I0402 02:18:50.813567 139678128547648 model_lib_v2.py:708] {'Loss/classification_loss': 0.4912954,
#  'Loss/localization_loss': 0.112246335,
#  'Loss/regularization_loss': 0.081970185,
#  'Loss/total_loss': 0.68551195,
#  'learning_rate': 0.044605974}
# INFO:tensorflow:Step 23800 per-step time 0.083s
# I0402 02:18:59.116181 139678128547648 model_lib_v2.py:705] Step 23800 per-step time 0.083s
# INFO:tensorflow:{'Loss/classification_loss': 0.079646535,
#  'Loss/localization_loss': 0.020704703,
#  'Loss/regularization_loss': 0.08178108,
#  'Loss/total_loss': 0.18213232,
#  'learning_rate': 0.044351134}
# I0402 02:18:59.116581 139678128547648 model_lib_v2.py:708] {'Loss/classification_loss': 0.079646535,
#  'Loss/localization_loss': 0.020704703,
#  'Loss/regularization_loss': 0.08178108,
#  'Loss/total_loss': 0.18213232,
#  'learning_rate': 0.044351134}
# INFO:tensorflow:Step 23900 per-step time 0.065s
# I0402 02:19:05.640220 139678128547648 model_lib_v2.py:705] Step 23900 per-step time 0.065s
# INFO:tensorflow:{'Loss/classification_loss': 0.08711542,
#  'Loss/localization_loss': 0.0999134,
#  'Loss/regularization_loss': 0.08159207,
#  'Loss/total_loss': 0.2686209,
#  'learning_rate': 0.044096105}
# I0402 02:19:05.640543 139678128547648 model_lib_v2.py:708] {'Loss/classification_loss': 0.08711542,
#  'Loss/localization_loss': 0.0999134,
#  'Loss/regularization_loss': 0.08159207,
#  'Loss/total_loss': 0.2686209,
#  'learning_rate': 0.044096105}
# INFO:tensorflow:Step 24000 per-step time 0.062s
# I0402 02:19:11.820114 139678128547648 model_lib_v2.py:705] Step 24000 per-step time 0.062s
# INFO:tensorflow:{'Loss/classification_loss': 0.09043145,
#  'Loss/localization_loss': 0.036691558,
#  'Loss/regularization_loss': 0.081378445,
#  'Loss/total_loss': 0.20850146,
#  'learning_rate': 0.043840922}
# I0402 02:19:11.820482 139678128547648 model_lib_v2.py:708] {'Loss/classification_loss': 0.09043145,
#  'Loss/localization_loss': 0.036691558,
#  'Loss/regularization_loss': 0.081378445,
#  'Loss/total_loss': 0.20850146,
#  'learning_rate': 0.043840922}
# INFO:tensorflow:Step 24100 per-step time 0.098s
# I0402 02:19:21.586222 139678128547648 model_lib_v2.py:705] Step 24100 per-step time 0.098s
# INFO:tensorflow:{'Loss/classification_loss': 0.22325225,
#  'Loss/localization_loss': 0.041169003,
#  'Loss/regularization_loss': 0.081184186,
#  'Loss/total_loss': 0.34560543,
#  'learning_rate': 0.043585572}
# I0402 02:19:21.586525 139678128547648 model_lib_v2.py:708] {'Loss/classification_loss': 0.22325225,
#  'Loss/localization_loss': 0.041169003,
#  'Loss/regularization_loss': 0.081184186,
#  'Loss/total_loss': 0.34560543,
#  'learning_rate': 0.043585572}
# INFO:tensorflow:Step 24200 per-step time 0.060s
# I0402 02:19:27.579173 139678128547648 model_lib_v2.py:705] Step 24200 per-step time 0.060s
# INFO:tensorflow:{'Loss/classification_loss': 0.055967197,
#  'Loss/localization_loss': 0.029186184,
#  'Loss/regularization_loss': 0.08097344,
#  'Loss/total_loss': 0.16612682,
#  'learning_rate': 0.043330073}
# I0402 02:19:27.579468 139678128547648 model_lib_v2.py:708] {'Loss/classification_loss': 0.055967197,
#  'Loss/localization_loss': 0.029186184,
#  'Loss/regularization_loss': 0.08097344,
#  'Loss/total_loss': 0.16612682,
#  'learning_rate': 0.043330073}
# INFO:tensorflow:Step 24300 per-step time 0.072s
# I0402 02:19:34.757678 139678128547648 model_lib_v2.py:705] Step 24300 per-step time 0.072s
# INFO:tensorflow:{'Loss/classification_loss': 0.07230477,
#  'Loss/localization_loss': 0.02418467,
#  'Loss/regularization_loss': 0.080806024,
#  'Loss/total_loss': 0.17729548,
#  'learning_rate': 0.04307444}
# I0402 02:19:34.758097 139678128547648 model_lib_v2.py:708] {'Loss/classification_loss': 0.07230477,
#  'Loss/localization_loss': 0.02418467,
#  'Loss/regularization_loss': 0.080806024,
#  'Loss/total_loss': 0.17729548,
#  'learning_rate': 0.04307444}
# INFO:tensorflow:Step 24400 per-step time 0.076s
# I0402 02:19:42.382913 139678128547648 model_lib_v2.py:705] Step 24400 per-step time 0.076s
# INFO:tensorflow:{'Loss/classification_loss': 0.11181675,
#  'Loss/localization_loss': 0.027028978,
#  'Loss/regularization_loss': 0.08062725,
#  'Loss/total_loss': 0.21947297,
#  'learning_rate': 0.04281868}
# I0402 02:19:42.383210 139678128547648 model_lib_v2.py:708] {'Loss/classification_loss': 0.11181675,
#  'Loss/localization_loss': 0.027028978,
#  'Loss/regularization_loss': 0.08062725,
#  'Loss/total_loss': 0.21947297,
#  'learning_rate': 0.04281868}
# INFO:tensorflow:Step 24500 per-step time 0.059s
# I0402 02:19:48.328180 139678128547648 model_lib_v2.py:705] Step 24500 per-step time 0.059s
# INFO:tensorflow:{'Loss/classification_loss': 0.052631676,
#  'Loss/localization_loss': 0.04457644,
#  'Loss/regularization_loss': 0.08045727,
#  'Loss/total_loss': 0.17766538,
#  'learning_rate': 0.042562805}
# I0402 02:19:48.328470 139678128547648 model_lib_v2.py:708] {'Loss/classification_loss': 0.052631676,
#  'Loss/localization_loss': 0.04457644,
#  'Loss/regularization_loss': 0.08045727,
#  'Loss/total_loss': 0.17766538,
#  'learning_rate': 0.042562805}
# INFO:tensorflow:Step 24600 per-step time 0.080s
# I0402 02:19:56.284362 139678128547648 model_lib_v2.py:705] Step 24600 per-step time 0.080s
# INFO:tensorflow:{'Loss/classification_loss': 0.12449023,
#  'Loss/localization_loss': 0.0642214,
#  'Loss/regularization_loss': 0.08026342,
#  'Loss/total_loss': 0.26897505,
#  'learning_rate': 0.04230683}
# I0402 02:19:56.284700 139678128547648 model_lib_v2.py:708] {'Loss/classification_loss': 0.12449023,
#  'Loss/localization_loss': 0.0642214,
#  'Loss/regularization_loss': 0.08026342,
#  'Loss/total_loss': 0.26897505,
#  'learning_rate': 0.04230683}
# INFO:tensorflow:Step 24700 per-step time 0.094s
# I0402 02:20:05.728695 139678128547648 model_lib_v2.py:705] Step 24700 per-step time 0.094s
# INFO:tensorflow:{'Loss/classification_loss': 0.05162653,
#  'Loss/localization_loss': 0.029160786,
#  'Loss/regularization_loss': 0.08007735,
#  'Loss/total_loss': 0.16086467,
#  'learning_rate': 0.042050745}
# I0402 02:20:05.730576 139678128547648 model_lib_v2.py:708] {'Loss/classification_loss': 0.05162653,
#  'Loss/localization_loss': 0.029160786,
#  'Loss/regularization_loss': 0.08007735,
#  'Loss/total_loss': 0.16086467,
#  'learning_rate': 0.042050745}
# INFO:tensorflow:Step 24800 per-step time 0.065s
# I0402 02:20:12.239397 139678128547648 model_lib_v2.py:705] Step 24800 per-step time 0.065s
# INFO:tensorflow:{'Loss/classification_loss': 0.09572368,
#  'Loss/localization_loss': 0.02541739,
#  'Loss/regularization_loss': 0.07988437,
#  'Loss/total_loss': 0.20102544,
#  'learning_rate': 0.04179459}
# I0402 02:20:12.239731 139678128547648 model_lib_v2.py:708] {'Loss/classification_loss': 0.09572368,
#  'Loss/localization_loss': 0.02541739,
#  'Loss/regularization_loss': 0.07988437,
#  'Loss/total_loss': 0.20102544,
#  'learning_rate': 0.04179459}
# INFO:tensorflow:Step 24900 per-step time 0.069s
# I0402 02:20:19.176381 139678128547648 model_lib_v2.py:705] Step 24900 per-step time 0.069s
# INFO:tensorflow:{'Loss/classification_loss': 0.15577891,
#  'Loss/localization_loss': 0.085702606,
#  'Loss/regularization_loss': 0.07969995,
#  'Loss/total_loss': 0.32118148,
#  'learning_rate': 0.04153835}
# I0402 02:20:19.176763 139678128547648 model_lib_v2.py:708] {'Loss/classification_loss': 0.15577891,
#  'Loss/localization_loss': 0.085702606,
#  'Loss/regularization_loss': 0.07969995,
#  'Loss/total_loss': 0.32118148,
#  'learning_rate': 0.04153835}
# INFO:tensorflow:Step 25000 per-step time 0.078s
# I0402 02:20:26.923320 139678128547648 model_lib_v2.py:705] Step 25000 per-step time 0.078s
# INFO:tensorflow:{'Loss/classification_loss': 0.060833618,
#  'Loss/localization_loss': 0.024416465,
#  'Loss/regularization_loss': 0.07984839,
#  'Loss/total_loss': 0.16509846,
#  'learning_rate': 0.04128206}
# I0402 02:20:26.923617 139678128547648 model_lib_v2.py:708] {'Loss/classification_loss': 0.060833618,
#  'Loss/localization_loss': 0.024416465,
#  'Loss/regularization_loss': 0.07984839,
#  'Loss/total_loss': 0.16509846,
#  'learning_rate': 0.04128206}
# INFO:tensorflow:Step 25100 per-step time 0.071s
# I0402 02:20:34.037461 139678128547648 model_lib_v2.py:705] Step 25100 per-step time 0.071s
# INFO:tensorflow:{'Loss/classification_loss': 0.07012116,
#  'Loss/localization_loss': 0.029418772,
#  'Loss/regularization_loss': 0.07973436,
#  'Loss/total_loss': 0.17927429,
#  'learning_rate': 0.041025713}
# I0402 02:20:34.037818 139678128547648 model_lib_v2.py:708] {'Loss/classification_loss': 0.07012116,
#  'Loss/localization_loss': 0.029418772,
#  'Loss/regularization_loss': 0.07973436,
#  'Loss/total_loss': 0.17927429,
#  'learning_rate': 0.041025713}
# INFO:tensorflow:Step 25200 per-step time 0.078s
# I0402 02:20:41.859783 139678128547648 model_lib_v2.py:705] Step 25200 per-step time 0.078s
# INFO:tensorflow:{'Loss/classification_loss': 0.07615321,
#  'Loss/localization_loss': 0.032867454,
#  'Loss/regularization_loss': 0.079694115,
#  'Loss/total_loss': 0.18871477,
#  'learning_rate': 0.04076932}
# I0402 02:20:41.860215 139678128547648 model_lib_v2.py:708] {'Loss/classification_loss': 0.07615321,
#  'Loss/localization_loss': 0.032867454,
#  'Loss/regularization_loss': 0.079694115,
#  'Loss/total_loss': 0.18871477,
#  'learning_rate': 0.04076932}
# INFO:tensorflow:Step 25300 per-step time 0.068s
# I0402 02:20:48.656199 139678128547648 model_lib_v2.py:705] Step 25300 per-step time 0.068s
# INFO:tensorflow:{'Loss/classification_loss': 0.082191266,
#  'Loss/localization_loss': 0.025358278,
#  'Loss/regularization_loss': 0.07963573,
#  'Loss/total_loss': 0.18718529,
#  'learning_rate': 0.0405129}
# I0402 02:20:48.656512 139678128547648 model_lib_v2.py:708] {'Loss/classification_loss': 0.082191266,
#  'Loss/localization_loss': 0.025358278,
#  'Loss/regularization_loss': 0.07963573,
#  'Loss/total_loss': 0.18718529,
#  'learning_rate': 0.0405129}
# INFO:tensorflow:Step 25400 per-step time 0.061s
# I0402 02:20:54.732140 139678128547648 model_lib_v2.py:705] Step 25400 per-step time 0.061s
# INFO:tensorflow:{'Loss/classification_loss': 0.12654689,
#  'Loss/localization_loss': 0.057751443,
#  'Loss/regularization_loss': 0.07946758,
#  'Loss/total_loss': 0.26376593,
#  'learning_rate': 0.04025645}
# I0402 02:20:54.732434 139678128547648 model_lib_v2.py:708] {'Loss/classification_loss': 0.12654689,
#  'Loss/localization_loss': 0.057751443,
#  'Loss/regularization_loss': 0.07946758,
#  'Loss/total_loss': 0.26376593,
#  'learning_rate': 0.04025645}
# INFO:tensorflow:Step 25500 per-step time 0.083s
# I0402 02:21:03.079561 139678128547648 model_lib_v2.py:705] Step 25500 per-step time 0.083s
# INFO:tensorflow:{'Loss/classification_loss': 0.11703571,
#  'Loss/localization_loss': 0.015518312,
#  'Loss/regularization_loss': 0.079277635,
#  'Loss/total_loss': 0.21183166,
#  'learning_rate': 0.039999995}
# I0402 02:21:03.080010 139678128547648 model_lib_v2.py:708] {'Loss/classification_loss': 0.11703571,
#  'Loss/localization_loss': 0.015518312,
#  'Loss/regularization_loss': 0.079277635,
#  'Loss/total_loss': 0.21183166,
#  'learning_rate': 0.039999995}
# INFO:tensorflow:Step 25600 per-step time 0.064s
# I0402 02:21:09.491987 139678128547648 model_lib_v2.py:705] Step 25600 per-step time 0.064s
# INFO:tensorflow:{'Loss/classification_loss': 0.07240921,
#  'Loss/localization_loss': 0.030228626,
#  'Loss/regularization_loss': 0.079091385,
#  'Loss/total_loss': 0.18172923,
#  'learning_rate': 0.039743543}
# I0402 02:21:09.492292 139678128547648 model_lib_v2.py:708] {'Loss/classification_loss': 0.07240921,
#  'Loss/localization_loss': 0.030228626,
#  'Loss/regularization_loss': 0.079091385,
#  'Loss/total_loss': 0.18172923,
#  'learning_rate': 0.039743543}
# INFO:tensorflow:Step 25700 per-step time 0.064s
# I0402 02:21:15.854836 139678128547648 model_lib_v2.py:705] Step 25700 per-step time 0.064s
# INFO:tensorflow:{'Loss/classification_loss': 0.07770949,
#  'Loss/localization_loss': 0.11221759,
#  'Loss/regularization_loss': 0.07889756,
#  'Loss/total_loss': 0.26882464,
#  'learning_rate': 0.039487097}
# I0402 02:21:15.855217 139678128547648 model_lib_v2.py:708] {'Loss/classification_loss': 0.07770949,
#  'Loss/localization_loss': 0.11221759,
#  'Loss/regularization_loss': 0.07889756,
#  'Loss/total_loss': 0.26882464,
#  'learning_rate': 0.039487097}
# INFO:tensorflow:Step 25800 per-step time 0.083s
# I0402 02:21:24.103903 139678128547648 model_lib_v2.py:705] Step 25800 per-step time 0.083s
# INFO:tensorflow:{'Loss/classification_loss': 0.09607166,
#  'Loss/localization_loss': 0.024946382,
#  'Loss/regularization_loss': 0.07871107,
#  'Loss/total_loss': 0.19972911,
#  'learning_rate': 0.03923067}
# I0402 02:21:24.104207 139678128547648 model_lib_v2.py:708] {'Loss/classification_loss': 0.09607166,
#  'Loss/localization_loss': 0.024946382,
#  'Loss/regularization_loss': 0.07871107,
#  'Loss/total_loss': 0.19972911,
#  'learning_rate': 0.03923067}
# INFO:tensorflow:Step 25900 per-step time 0.060s
# I0402 02:21:30.076731 139678128547648 model_lib_v2.py:705] Step 25900 per-step time 0.060s
# INFO:tensorflow:{'Loss/classification_loss': 0.09174238,
#  'Loss/localization_loss': 0.0702941,
#  'Loss/regularization_loss': 0.078530185,
#  'Loss/total_loss': 0.24056667,
#  'learning_rate': 0.038974285}
# I0402 02:21:30.077061 139678128547648 model_lib_v2.py:708] {'Loss/classification_loss': 0.09174238,
#  'Loss/localization_loss': 0.0702941,
#  'Loss/regularization_loss': 0.078530185,
#  'Loss/total_loss': 0.24056667,
#  'learning_rate': 0.038974285}
# INFO:tensorflow:Step 26000 per-step time 0.067s
# I0402 02:21:36.782458 139678128547648 model_lib_v2.py:705] Step 26000 per-step time 0.067s
# INFO:tensorflow:{'Loss/classification_loss': 0.08384884,
#  'Loss/localization_loss': 0.026207168,
#  'Loss/regularization_loss': 0.078378536,
#  'Loss/total_loss': 0.18843454,
#  'learning_rate': 0.038717933}
# I0402 02:21:36.782781 139678128547648 model_lib_v2.py:708] {'Loss/classification_loss': 0.08384884,
#  'Loss/localization_loss': 0.026207168,
#  'Loss/regularization_loss': 0.078378536,
#  'Loss/total_loss': 0.18843454,
#  'learning_rate': 0.038717933}
# INFO:tensorflow:Step 26100 per-step time 0.090s
# I0402 02:21:45.798533 139678128547648 model_lib_v2.py:705] Step 26100 per-step time 0.090s
# INFO:tensorflow:{'Loss/classification_loss': 0.06757075,
#  'Loss/localization_loss': 0.039142173,
#  'Loss/regularization_loss': 0.07821992,
#  'Loss/total_loss': 0.18493284,
#  'learning_rate': 0.038461637}
# I0402 02:21:45.798824 139678128547648 model_lib_v2.py:708] {'Loss/classification_loss': 0.06757075,
#  'Loss/localization_loss': 0.039142173,
#  'Loss/regularization_loss': 0.07821992,
#  'Loss/total_loss': 0.18493284,
#  'learning_rate': 0.038461637}
# INFO:tensorflow:Step 26200 per-step time 0.060s
# I0402 02:21:51.825965 139678128547648 model_lib_v2.py:705] Step 26200 per-step time 0.060s
# INFO:tensorflow:{'Loss/classification_loss': 0.07509695,
#  'Loss/localization_loss': 0.025960982,
#  'Loss/regularization_loss': 0.07806916,
#  'Loss/total_loss': 0.1791271,
#  'learning_rate': 0.038205404}
# ...
#  'Loss/localization_loss': 0.038483087,
#  'Loss/regularization_loss': 0.06414024,
#  'Loss/total_loss': 0.1618366,
#  'learning_rate': 0.000642817}
# INFO:tensorflow:Step 47300 per-step time 0.068s
# I0402 02:47:00.039478 139678128547648 model_lib_v2.py:705] Step 47300 per-step time 0.068s
# INFO:tensorflow:{'Loss/classification_loss': 0.091736875,
#  'Loss/localization_loss': 0.032726552,
#  'Loss/regularization_loss': 0.06413703,
#  'Loss/total_loss': 0.18860045,
#  'learning_rate': 0.0005978322}
# I0402 02:47:00.039779 139678128547648 model_lib_v2.py:708] {'Loss/classification_loss': 0.091736875,
#  'Loss/localization_loss': 0.032726552,
#  'Loss/regularization_loss': 0.06413703,
#  'Loss/total_loss': 0.18860045,
#  'learning_rate': 0.0005978322}
# INFO:tensorflow:Step 47400 per-step time 0.060s
# I0402 02:47:06.000775 139678128547648 model_lib_v2.py:705] Step 47400 per-step time 0.060s
# INFO:tensorflow:{'Loss/classification_loss': 0.03271308,
#  'Loss/localization_loss': 0.008490401,
#  'Loss/regularization_loss': 0.06413413,
#  'Loss/total_loss': 0.10533761,
#  'learning_rate': 0.000554471}
# I0402 02:47:06.001077 139678128547648 model_lib_v2.py:708] {'Loss/classification_loss': 0.03271308,
#  'Loss/localization_loss': 0.008490401,
#  'Loss/regularization_loss': 0.06413413,
#  'Loss/total_loss': 0.10533761,
#  'learning_rate': 0.000554471}
# INFO:tensorflow:Step 47500 per-step time 0.079s
# I0402 02:47:13.923546 139678128547648 model_lib_v2.py:705] Step 47500 per-step time 0.079s
# INFO:tensorflow:{'Loss/classification_loss': 0.044006504,
#  'Loss/localization_loss': 0.00782594,
#  'Loss/regularization_loss': 0.06413136,
#  'Loss/total_loss': 0.1159638,
#  'learning_rate': 0.0005127263}
# I0402 02:47:13.923947 139678128547648 model_lib_v2.py:708] {'Loss/classification_loss': 0.044006504,
#  'Loss/localization_loss': 0.00782594,
#  'Loss/regularization_loss': 0.06413136,
#  'Loss/total_loss': 0.1159638,
#  'learning_rate': 0.0005127263}
# INFO:tensorflow:Step 47600 per-step time 0.065s
# I0402 02:47:20.375385 139678128547648 model_lib_v2.py:705] Step 47600 per-step time 0.065s
# INFO:tensorflow:{'Loss/classification_loss': 0.040073406,
#  'Loss/localization_loss': 0.013287142,
#  'Loss/regularization_loss': 0.0641288,
#  'Loss/total_loss': 0.11748935,
#  'learning_rate': 0.00047260997}
# I0402 02:47:20.375670 139678128547648 model_lib_v2.py:708] {'Loss/classification_loss': 0.040073406,
#  'Loss/localization_loss': 0.013287142,
#  'Loss/regularization_loss': 0.0641288,
#  'Loss/total_loss': 0.11748935,
#  'learning_rate': 0.00047260997}
# INFO:tensorflow:Step 47700 per-step time 0.078s
# I0402 02:47:28.134388 139678128547648 model_lib_v2.py:705] Step 47700 per-step time 0.078s
# INFO:tensorflow:{'Loss/classification_loss': 0.07260364,
#  'Loss/localization_loss': 0.02464338,
#  'Loss/regularization_loss': 0.064126514,
#  'Loss/total_loss': 0.16137353,
#  'learning_rate': 0.0004341173}
# I0402 02:47:28.134749 139678128547648 model_lib_v2.py:708] {'Loss/classification_loss': 0.07260364,
#  'Loss/localization_loss': 0.02464338,
#  'Loss/regularization_loss': 0.064126514,
#  'Loss/total_loss': 0.16137353,
#  'learning_rate': 0.0004341173}
# INFO:tensorflow:Step 47800 per-step time 0.089s
# I0402 02:47:37.001616 139678128547648 model_lib_v2.py:705] Step 47800 per-step time 0.089s
# INFO:tensorflow:{'Loss/classification_loss': 0.043534733,
#  'Loss/localization_loss': 0.010717643,
#  'Loss/regularization_loss': 0.06412442,
#  'Loss/total_loss': 0.1183768,
#  'learning_rate': 0.00039724825}
# I0402 02:47:37.001978 139678128547648 model_lib_v2.py:708] {'Loss/classification_loss': 0.043534733,
#  'Loss/localization_loss': 0.010717643,
#  'Loss/regularization_loss': 0.06412442,
#  'Loss/total_loss': 0.1183768,
#  'learning_rate': 0.00039724825}
# INFO:tensorflow:Step 47900 per-step time 0.064s
# I0402 02:47:43.371277 139678128547648 model_lib_v2.py:705] Step 47900 per-step time 0.064s
# INFO:tensorflow:{'Loss/classification_loss': 0.042459827,
#  'Loss/localization_loss': 0.017095456,
#  'Loss/regularization_loss': 0.06412247,
#  'Loss/total_loss': 0.12367775,
#  'learning_rate': 0.00036200762}
# I0402 02:47:43.371568 139678128547648 model_lib_v2.py:708] {'Loss/classification_loss': 0.042459827,
#  'Loss/localization_loss': 0.017095456,
#  'Loss/regularization_loss': 0.06412247,
#  'Loss/total_loss': 0.12367775,
#  'learning_rate': 0.00036200762}
# INFO:tensorflow:Step 48000 per-step time 0.062s
# I0402 02:47:49.551176 139678128547648 model_lib_v2.py:705] Step 48000 per-step time 0.062s
# INFO:tensorflow:{'Loss/classification_loss': 0.060060956,
#  'Loss/localization_loss': 0.012184307,
#  'Loss/regularization_loss': 0.064120695,
#  'Loss/total_loss': 0.13636595,
#  'learning_rate': 0.00032839776}
# I0402 02:47:49.551512 139678128547648 model_lib_v2.py:708] {'Loss/classification_loss': 0.060060956,
#  'Loss/localization_loss': 0.012184307,
#  'Loss/regularization_loss': 0.064120695,
#  'Loss/total_loss': 0.13636595,
#  'learning_rate': 0.00032839776}
# INFO:tensorflow:Step 48100 per-step time 0.091s
# I0402 02:47:58.688182 139678128547648 model_lib_v2.py:705] Step 48100 per-step time 0.091s
# INFO:tensorflow:{'Loss/classification_loss': 0.3138231,
#  'Loss/localization_loss': 0.124002255,
#  'Loss/regularization_loss': 0.06411904,
#  'Loss/total_loss': 0.5019444,
#  'learning_rate': 0.00029641867}
# I0402 02:47:58.688478 139678128547648 model_lib_v2.py:708] {'Loss/classification_loss': 0.3138231,
#  'Loss/localization_loss': 0.124002255,
#  'Loss/regularization_loss': 0.06411904,
#  'Loss/total_loss': 0.5019444,
#  'learning_rate': 0.00029641867}
# INFO:tensorflow:Step 48200 per-step time 0.058s
# I0402 02:48:04.527103 139678128547648 model_lib_v2.py:705] Step 48200 per-step time 0.058s
# INFO:tensorflow:{'Loss/classification_loss': 0.068613864,
#  'Loss/localization_loss': 0.026426928,
#  'Loss/regularization_loss': 0.06411757,
#  'Loss/total_loss': 0.15915836,
#  'learning_rate': 0.00026607275}
# I0402 02:48:04.527419 139678128547648 model_lib_v2.py:708] {'Loss/classification_loss': 0.068613864,
#  'Loss/localization_loss': 0.026426928,
#  'Loss/regularization_loss': 0.06411757,
#  'Loss/total_loss': 0.15915836,
#  'learning_rate': 0.00026607275}
# INFO:tensorflow:Step 48300 per-step time 0.072s
# I0402 02:48:11.722259 139678128547648 model_lib_v2.py:705] Step 48300 per-step time 0.072s
# INFO:tensorflow:{'Loss/classification_loss': 0.061873738,
#  'Loss/localization_loss': 0.024288248,
#  'Loss/regularization_loss': 0.06411626,
#  'Loss/total_loss': 0.15027824,
#  'learning_rate': 0.00023735761}
# I0402 02:48:11.722624 139678128547648 model_lib_v2.py:708] {'Loss/classification_loss': 0.061873738,
#  'Loss/localization_loss': 0.024288248,
#  'Loss/regularization_loss': 0.06411626,
#  'Loss/total_loss': 0.15027824,
#  'learning_rate': 0.00023735761}
# INFO:tensorflow:Step 48400 per-step time 0.072s
# I0402 02:48:18.927917 139678128547648 model_lib_v2.py:705] Step 48400 per-step time 0.072s
# INFO:tensorflow:{'Loss/classification_loss': 0.02235881,
#  'Loss/localization_loss': 0.005094577,
#  'Loss/regularization_loss': 0.06411511,
#  'Loss/total_loss': 0.09156849,
#  'learning_rate': 0.00021027803}
# I0402 02:48:18.928221 139678128547648 model_lib_v2.py:708] {'Loss/classification_loss': 0.02235881,
#  'Loss/localization_loss': 0.005094577,
#  'Loss/regularization_loss': 0.06411511,
#  'Loss/total_loss': 0.09156849,
#  'learning_rate': 0.00021027803}
# INFO:tensorflow:Step 48500 per-step time 0.060s
# I0402 02:48:24.892399 139678128547648 model_lib_v2.py:705] Step 48500 per-step time 0.060s
# INFO:tensorflow:{'Loss/classification_loss': 0.0621553,
#  'Loss/localization_loss': 0.008230564,
#  'Loss/regularization_loss': 0.06411409,
#  'Loss/total_loss': 0.13449995,
#  'learning_rate': 0.000184834}
# I0402 02:48:24.892678 139678128547648 model_lib_v2.py:708] {'Loss/classification_loss': 0.0621553,
#  'Loss/localization_loss': 0.008230564,
#  'Loss/regularization_loss': 0.06411409,
#  'Loss/total_loss': 0.13449995,
#  'learning_rate': 0.000184834}
# INFO:tensorflow:Step 48600 per-step time 0.075s
# I0402 02:48:32.438224 139678128547648 model_lib_v2.py:705] Step 48600 per-step time 0.075s
# INFO:tensorflow:{'Loss/classification_loss': 0.049392805,
#  'Loss/localization_loss': 0.0063101305,
#  'Loss/regularization_loss': 0.06411318,
#  'Loss/total_loss': 0.11981611,
#  'learning_rate': 0.0001610279}
# I0402 02:48:32.438606 139678128547648 model_lib_v2.py:708] {'Loss/classification_loss': 0.049392805,
#  'Loss/localization_loss': 0.0063101305,
#  'Loss/regularization_loss': 0.06411318,
#  'Loss/total_loss': 0.11981611,
#  'learning_rate': 0.0001610279}
# INFO:tensorflow:Step 48700 per-step time 0.066s
# I0402 02:48:39.075730 139678128547648 model_lib_v2.py:705] Step 48700 per-step time 0.066s
# INFO:tensorflow:{'Loss/classification_loss': 0.055876873,
#  'Loss/localization_loss': 0.02267763,
#  'Loss/regularization_loss': 0.064112365,
#  'Loss/total_loss': 0.14266688,
#  'learning_rate': 0.00013885974}
# I0402 02:48:39.076049 139678128547648 model_lib_v2.py:708] {'Loss/classification_loss': 0.055876873,
#  'Loss/localization_loss': 0.02267763,
#  'Loss/regularization_loss': 0.064112365,
#  'Loss/total_loss': 0.14266688,
#  'learning_rate': 0.00013885974}
# INFO:tensorflow:Step 48800 per-step time 0.060s
# I0402 02:48:45.109752 139678128547648 model_lib_v2.py:705] Step 48800 per-step time 0.060s
# INFO:tensorflow:{'Loss/classification_loss': 0.15055662,
#  'Loss/localization_loss': 0.020281851,
#  'Loss/regularization_loss': 0.06411171,
#  'Loss/total_loss': 0.23495018,
#  'learning_rate': 0.00011832714}
# I0402 02:48:45.110072 139678128547648 model_lib_v2.py:708] {'Loss/classification_loss': 0.15055662,
#  'Loss/localization_loss': 0.020281851,
#  'Loss/regularization_loss': 0.06411171,
#  'Loss/total_loss': 0.23495018,
#  'learning_rate': 0.00011832714}
# INFO:tensorflow:Step 48900 per-step time 0.082s
# I0402 02:48:53.298039 139678128547648 model_lib_v2.py:705] Step 48900 per-step time 0.082s
# INFO:tensorflow:{'Loss/classification_loss': 0.07929678,
#  'Loss/localization_loss': 0.025238363,
#  'Loss/regularization_loss': 0.06411113,
#  'Loss/total_loss': 0.16864628,
#  'learning_rate': 9.943485e-05}
# I0402 02:48:53.298382 139678128547648 model_lib_v2.py:708] {'Loss/classification_loss': 0.07929678,
#  'Loss/localization_loss': 0.025238363,
#  'Loss/regularization_loss': 0.06411113,
#  'Loss/total_loss': 0.16864628,
#  'learning_rate': 9.943485e-05}
# INFO:tensorflow:Step 49000 per-step time 0.062s
# I0402 02:48:59.512161 139678128547648 model_lib_v2.py:705] Step 49000 per-step time 0.062s
# INFO:tensorflow:{'Loss/classification_loss': 0.060844515,
#  'Loss/localization_loss': 0.012007697,
#  'Loss/regularization_loss': 0.06411065,
#  'Loss/total_loss': 0.13696286,
#  'learning_rate': 8.218288e-05}
# I0402 02:48:59.512450 139678128547648 model_lib_v2.py:708] {'Loss/classification_loss': 0.060844515,
#  'Loss/localization_loss': 0.012007697,
#  'Loss/regularization_loss': 0.06411065,
#  'Loss/total_loss': 0.13696286,
#  'learning_rate': 8.218288e-05}
# INFO:tensorflow:Step 49100 per-step time 0.085s
# I0402 02:49:08.023744 139678128547648 model_lib_v2.py:705] Step 49100 per-step time 0.085s
# INFO:tensorflow:{'Loss/classification_loss': 0.38590968,
#  'Loss/localization_loss': 0.055514302,
#  'Loss/regularization_loss': 0.06411027,
#  'Loss/total_loss': 0.50553423,
#  'learning_rate': 6.6573615e-05}
# I0402 02:49:08.024122 139678128547648 model_lib_v2.py:708] {'Loss/classification_loss': 0.38590968,
#  'Loss/localization_loss': 0.055514302,
#  'Loss/regularization_loss': 0.06411027,
#  'Loss/total_loss': 0.50553423,
#  'learning_rate': 6.6573615e-05}
# INFO:tensorflow:Step 49200 per-step time 0.073s
# I0402 02:49:15.343177 139678128547648 model_lib_v2.py:705] Step 49200 per-step time 0.073s
# INFO:tensorflow:{'Loss/classification_loss': 0.08927837,
#  'Loss/localization_loss': 0.0134005025,
#  'Loss/regularization_loss': 0.06410995,
#  'Loss/total_loss': 0.16678882,
#  'learning_rate': 5.2604675e-05}
# I0402 02:49:15.343459 139678128547648 model_lib_v2.py:708] {'Loss/classification_loss': 0.08927837,
#  'Loss/localization_loss': 0.0134005025,
#  'Loss/regularization_loss': 0.06410995,
#  'Loss/total_loss': 0.16678882,
#  'learning_rate': 5.2604675e-05}
# INFO:tensorflow:Step 49400 per-step time 0.075s
# I0402 02:49:28.796757 139678128547648 model_lib_v2.py:705] Step 49400 per-step time 0.075s
# INFO:tensorflow:{'Loss/classification_loss': 0.10045001,
#  'Loss/localization_loss': 0.01823796,
#  'Loss/regularization_loss': 0.064109534,
#  'Loss/total_loss': 0.1827975,
#  'learning_rate': 2.9592513e-05}
# I0402 02:49:28.797299 139678128547648 model_lib_v2.py:708] {'Loss/classification_loss': 0.10045001,
#  'Loss/localization_loss': 0.01823796,
#  'Loss/regularization_loss': 0.064109534,
#  'Loss/total_loss': 0.1827975,
#  'learning_rate': 2.9592513e-05}
# INFO:tensorflow:Step 49500 per-step time 0.082s
# I0402 02:49:36.978923 139678128547648 model_lib_v2.py:705] Step 49500 per-step time 0.082s
# INFO:tensorflow:{'Loss/classification_loss': 0.050302487,
#  'Loss/localization_loss': 0.020469686,
#  'Loss/regularization_loss': 0.0641094,
#  'Loss/total_loss': 0.13488157,
#  'learning_rate': 2.055168e-05}
# I0402 02:49:36.979299 139678128547648 model_lib_v2.py:708] {'Loss/classification_loss': 0.050302487,
#  'Loss/localization_loss': 0.020469686,
#  'Loss/regularization_loss': 0.0641094,
#  'Loss/total_loss': 0.13488157,
#  'learning_rate': 2.055168e-05}
# INFO:tensorflow:Step 49600 per-step time 0.077s
# I0402 02:49:44.676598 139678128547648 model_lib_v2.py:705] Step 49600 per-step time 0.077s
# INFO:tensorflow:{'Loss/classification_loss': 0.060559493,
#  'Loss/localization_loss': 0.02939584,
#  'Loss/regularization_loss': 0.064109325,
#  'Loss/total_loss': 0.15406466,
#  'learning_rate': 1.3153553e-05}
# I0402 02:49:44.676948 139678128547648 model_lib_v2.py:708] {'Loss/classification_loss': 0.060559493,
#  'Loss/localization_loss': 0.02939584,
#  'Loss/regularization_loss': 0.064109325,
#  'Loss/total_loss': 0.15406466,
#  'learning_rate': 1.3153553e-05}
# INFO:tensorflow:Step 49700 per-step time 0.077s
# I0402 02:49:52.387975 139678128547648 model_lib_v2.py:705] Step 49700 per-step time 0.077s
# INFO:tensorflow:{'Loss/classification_loss': 0.08739363,
#  'Loss/localization_loss': 0.009256905,
#  'Loss/regularization_loss': 0.06410928,
#  'Loss/total_loss': 0.1607598,
#  'learning_rate': 7.398128e-06}
# I0402 02:49:52.388259 139678128547648 model_lib_v2.py:708] {'Loss/classification_loss': 0.08739363,
#  'Loss/localization_loss': 0.009256905,
#  'Loss/regularization_loss': 0.06410928,
#  'Loss/total_loss': 0.1607598,
#  'learning_rate': 7.398128e-06}
# INFO:tensorflow:Step 49800 per-step time 0.060s
# I0402 02:49:58.374931 139678128547648 model_lib_v2.py:705] Step 49800 per-step time 0.060s
# INFO:tensorflow:{'Loss/classification_loss': 0.16870072,
#  'Loss/localization_loss': 0.015679045,
#  'Loss/regularization_loss': 0.06410926,
#  'Loss/total_loss': 0.24848902,
#  'learning_rate': 3.2877922e-06}
# I0402 02:49:58.375238 139678128547648 model_lib_v2.py:708] {'Loss/classification_loss': 0.16870072,
#  'Loss/localization_loss': 0.015679045,
#  'Loss/regularization_loss': 0.06410926,
#  'Loss/total_loss': 0.24848902,
#  'learning_rate': 3.2877922e-06}
# INFO:tensorflow:Step 49900 per-step time 0.072s
# I0402 02:50:05.559059 139678128547648 model_lib_v2.py:705] Step 49900 per-step time 0.072s
# INFO:tensorflow:{'Loss/classification_loss': 0.021765117,
#  'Loss/localization_loss': 0.0071766316,
#  'Loss/regularization_loss': 0.06410925,
#  'Loss/total_loss': 0.093051,
#  'learning_rate': 8.2254405e-07}
# I0402 02:50:05.559414 139678128547648 model_lib_v2.py:708] {'Loss/classification_loss': 0.021765117,
#  'Loss/localization_loss': 0.0071766316,
#  'Loss/regularization_loss': 0.06410925,
#  'Loss/total_loss': 0.093051,
#  'learning_rate': 8.2254405e-07}
# INFO:tensorflow:Step 50000 per-step time 0.072s
# I0402 02:50:12.720620 139678128547648 model_lib_v2.py:705] Step 50000 per-step time 0.072s
# INFO:tensorflow:{'Loss/classification_loss': 0.0999785,
#  'Loss/localization_loss': 0.017345168,
#  'Loss/regularization_loss': 0.06410925,
#  'Loss/total_loss': 0.18143292,
#  'learning_rate': 0.0}
# I0402 02:50:12.720937 139678128547648 model_lib_v2.py:708] {'Loss/classification_loss': 0.0999785,
#  'Loss/localization_loss': 0.017345168,
#  'Loss/regularization_loss': 0.06410925,
#  'Loss/total_loss': 0.18143292,
#  'learning_rate': 0.0}

# %% [markdown]
# # 7. Evaluate the Model

# %%
command = "python {} --model_dir={} --pipeline_config_path={} --checkpoint_dir={}".format(TRAINING_SCRIPT, paths['CHECKPOINT_PATH'],files['PIPELINE_CONFIG'], paths['CHECKPOINT_PATH'])

# %%
print(command)
# Out:
# python Tensorflow/models/research/object_detection/model_main_tf2.py --model_dir=Tensorflow/workspace/models/my_ssd_mobnet --pipeline_config_path=Tensorflow/workspace/models/my_ssd_mobnet/pipeline.config --checkpoint_dir=Tensorflow/workspace/models/my_ssd_mobnet

# %%
# !{command}
# Out:
# 2023-04-02 01:39:56.217732: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# /usr/local/lib/python3.9/dist-packages/tensorflow_addons/utils/ensure_tf_install.py:53: UserWarning: Tensorflow Addons supports using Python ops for all Tensorflow versions above or equal to 2.9.0 and strictly below 2.12.0 (nightly versions are not supported).
#  The versions of TensorFlow you are currently using is 2.12.0 and is not supported.
# Some things might work, some things might not.
# If you were to encounter a bug, do not file an issue.
# If you want to make sure you're using a tested and supported configuration, either change the TensorFlow version or the TensorFlow Addons's version.
# You can find the compatibility matrix in TensorFlow Addon's readme:
# https://github.com/tensorflow/addons
#   warnings.warn(
# WARNING:tensorflow:Forced number of epochs for all eval validations to be 1.
# W0402 01:39:59.074681 140659525949248 model_lib_v2.py:1089] Forced number of epochs for all eval validations to be 1.
# INFO:tensorflow:Maybe overwriting sample_1_of_n_eval_examples: None
# I0402 01:39:59.074932 140659525949248 config_util.py:552] Maybe overwriting sample_1_of_n_eval_examples: None
# INFO:tensorflow:Maybe overwriting use_bfloat16: False
# I0402 01:39:59.075037 140659525949248 config_util.py:552] Maybe overwriting use_bfloat16: False
# INFO:tensorflow:Maybe overwriting eval_num_epochs: 1
# I0402 01:39:59.075120 140659525949248 config_util.py:552] Maybe overwriting eval_num_epochs: 1
# WARNING:tensorflow:Expected number of evaluation epochs is 1, but instead encountered `eval_on_train_input_config.num_epochs` = 0. Overwriting `num_epochs` to 1.
# W0402 01:39:59.075232 140659525949248 model_lib_v2.py:1106] Expected number of evaluation epochs is 1, but instead encountered `eval_on_train_input_config.num_epochs` = 0. Overwriting `num_epochs` to 1.
# 2023-04-02 01:40:00.125955: W tensorflow/core/common_runtime/gpu/gpu_bfc_allocator.cc:47] Overriding orig_value setting because the TF_FORCE_GPU_ALLOW_GROWTH environment variable is set. Original config value was 0.
# INFO:tensorflow:Reading unweighted datasets: ['Tensorflow/workspace/annotations/test.record']
# I0402 01:40:00.172574 140659525949248 dataset_builder.py:162] Reading unweighted datasets: ['Tensorflow/workspace/annotations/test.record']
# INFO:tensorflow:Reading record datasets for input file: ['Tensorflow/workspace/annotations/test.record']
# I0402 01:40:00.172797 140659525949248 dataset_builder.py:79] Reading record datasets for input file: ['Tensorflow/workspace/annotations/test.record']
# INFO:tensorflow:Number of filenames to read: 1
# I0402 01:40:00.172920 140659525949248 dataset_builder.py:80] Number of filenames to read: 1
# WARNING:tensorflow:num_readers has been reduced to 1 to match input file shards.
# W0402 01:40:00.172991 140659525949248 dataset_builder.py:86] num_readers has been reduced to 1 to match input file shards.
# WARNING:tensorflow:From /usr/local/lib/python3.9/dist-packages/object_detection/builders/dataset_builder.py:100: parallel_interleave (from tensorflow.python.data.experimental.ops.interleave_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.data.Dataset.interleave(map_func, cycle_length, block_length, num_parallel_calls=tf.data.AUTOTUNE)` instead. If sloppy execution is desired, use `tf.data.Options.deterministic`.
# W0402 01:40:00.176843 140659525949248 deprecation.py:364] From /usr/local/lib/python3.9/dist-packages/object_detection/builders/dataset_builder.py:100: parallel_interleave (from tensorflow.python.data.experimental.ops.interleave_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.data.Dataset.interleave(map_func, cycle_length, block_length, num_parallel_calls=tf.data.AUTOTUNE)` instead. If sloppy execution is desired, use `tf.data.Options.deterministic`.
# WARNING:tensorflow:From /usr/local/lib/python3.9/dist-packages/object_detection/builders/dataset_builder.py:235: DatasetV1.map_with_legacy_function (from tensorflow.python.data.ops.dataset_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.data.Dataset.map()
# W0402 01:40:00.195209 140659525949248 deprecation.py:364] From /usr/local/lib/python3.9/dist-packages/object_detection/builders/dataset_builder.py:235: DatasetV1.map_with_legacy_function (from tensorflow.python.data.ops.dataset_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.data.Dataset.map()
# WARNING:tensorflow:From /usr/local/lib/python3.9/dist-packages/tensorflow/python/util/dispatch.py:1176: sparse_to_dense (from tensorflow.python.ops.sparse_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Create a `tf.sparse.SparseTensor` and use `tf.sparse.to_dense` instead.
# W0402 01:40:04.562113 140659525949248 deprecation.py:364] From /usr/local/lib/python3.9/dist-packages/tensorflow/python/util/dispatch.py:1176: sparse_to_dense (from tensorflow.python.ops.sparse_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Create a `tf.sparse.SparseTensor` and use `tf.sparse.to_dense` instead.
# WARNING:tensorflow:From /usr/local/lib/python3.9/dist-packages/tensorflow/python/util/dispatch.py:1176: to_float (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.cast` instead.
# W0402 01:40:06.183896 140659525949248 deprecation.py:364] From /usr/local/lib/python3.9/dist-packages/tensorflow/python/util/dispatch.py:1176: to_float (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.cast` instead.
# WARNING:tensorflow:From /usr/local/lib/python3.9/dist-packages/object_detection/builders/optimizer_builder.py:124: The name tf.keras.optimizers.SGD is deprecated. Please use tf.keras.optimizers.legacy.SGD instead.
#
# W0402 01:40:10.300773 140659525949248 module_wrapper.py:149] From /usr/local/lib/python3.9/dist-packages/object_detection/builders/optimizer_builder.py:124: The name tf.keras.optimizers.SGD is deprecated. Please use tf.keras.optimizers.legacy.SGD instead.
#
# INFO:tensorflow:Waiting for new checkpoint at Tensorflow/workspace/models/my_ssd_mobnet
# I0402 01:40:10.301269 140659525949248 checkpoint_utils.py:168] Waiting for new checkpoint at Tensorflow/workspace/models/my_ssd_mobnet
# INFO:tensorflow:Found new checkpoint at Tensorflow/workspace/models/my_ssd_mobnet/ckpt-22
# I0402 01:40:10.302348 140659525949248 checkpoint_utils.py:177] Found new checkpoint at Tensorflow/workspace/models/my_ssd_mobnet/ckpt-22
# /usr/local/lib/python3.9/dist-packages/keras/backend.py:452: UserWarning: `tf.keras.backend.set_learning_phase` is deprecated and will be removed after 2020-10-11. To update it, simply pass a True/False value to the `training` argument of the `__call__` method of your layer or model.
#   warnings.warn(
# I0402 01:40:15.900834 140659525949248 api.py:459] feature_map_spatial_dims: [(40, 40), (20, 20), (10, 10), (5, 5), (3, 3)]
# I0402 01:40:29.922288 140659525949248 api.py:459] feature_map_spatial_dims: [(40, 40), (20, 20), (10, 10), (5, 5), (3, 3)]
# WARNING:tensorflow:From /usr/local/lib/python3.9/dist-packages/tensorflow/python/util/dispatch.py:1176: to_int64 (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.cast` instead.
# W0402 01:40:35.855212 140659525949248 deprecation.py:364] From /usr/local/lib/python3.9/dist-packages/tensorflow/python/util/dispatch.py:1176: to_int64 (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.cast` instead.
# INFO:tensorflow:Finished eval step 0
# I0402 01:40:35.883732 140659525949248 model_lib_v2.py:966] Finished eval step 0
# WARNING:tensorflow:From /usr/local/lib/python3.9/dist-packages/tensorflow/python/autograph/impl/api.py:459: py_func (from tensorflow.python.ops.script_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# tf.py_func is deprecated in TF V2. Instead, there are two
#     options available in V2.
#     - tf.py_function takes a python function which manipulates tf eager
#     tensors instead of numpy arrays. It's easy to convert a tf eager tensor to
#     an ndarray (just call tensor.numpy()) but having access to eager tensors
#     means `tf.py_function`s can use accelerators such as GPUs as well as
#     being differentiable using a gradient tape.
#     - tf.numpy_function maintains the semantics of the deprecated tf.py_func
#     (it is not differentiable, and manipulates numpy arrays). It drops the
#     stateful argument making all functions stateful.
#
# W0402 01:40:36.243264 140659525949248 deprecation.py:364] From /usr/local/lib/python3.9/dist-packages/tensorflow/python/autograph/impl/api.py:459: py_func (from tensorflow.python.ops.script_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# tf.py_func is deprecated in TF V2. Instead, there are two
#     options available in V2.
#     - tf.py_function takes a python function which manipulates tf eager
#     tensors instead of numpy arrays. It's easy to convert a tf eager tensor to
#     an ndarray (just call tensor.numpy()) but having access to eager tensors
#     means `tf.py_function`s can use accelerators such as GPUs as well as
#     being differentiable using a gradient tape.
#     - tf.numpy_function maintains the semantics of the deprecated tf.py_func
#     (it is not differentiable, and manipulates numpy arrays). It drops the
#     stateful argument making all functions stateful.
#
# DONE (t=0.37s).
# Accumulating evaluation results...
# DONE (t=0.06s).
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.669
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.955
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.835
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.663
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.759
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.724
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.727
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.729
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.718
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.818
# INFO:tensorflow:Eval metrics at step 20000
# I0402 01:40:52.237403 140659525949248 model_lib_v2.py:1015] Eval metrics at step 20000
# INFO:tensorflow:	+ DetectionBoxes_Precision/mAP: 0.668990
# I0402 01:40:52.245660 140659525949248 model_lib_v2.py:1018] 	+ DetectionBoxes_Precision/mAP: 0.668990
# INFO:tensorflow:	+ DetectionBoxes_Precision/mAP@.50IOU: 0.955126
# I0402 01:40:52.247434 140659525949248 model_lib_v2.py:1018] 	+ DetectionBoxes_Precision/mAP@.50IOU: 0.955126
# INFO:tensorflow:	+ DetectionBoxes_Precision/mAP@.75IOU: 0.835115
# I0402 01:40:52.249018 140659525949248 model_lib_v2.py:1018] 	+ DetectionBoxes_Precision/mAP@.75IOU: 0.835115
# INFO:tensorflow:	+ DetectionBoxes_Precision/mAP (small): -1.000000
# I0402 01:40:52.250512 140659525949248 model_lib_v2.py:1018] 	+ DetectionBoxes_Precision/mAP (small): -1.000000
# INFO:tensorflow:	+ DetectionBoxes_Precision/mAP (medium): 0.663299
# I0402 01:40:52.251952 140659525949248 model_lib_v2.py:1018] 	+ DetectionBoxes_Precision/mAP (medium): 0.663299
# INFO:tensorflow:	+ DetectionBoxes_Precision/mAP (large): 0.758546
# I0402 01:40:52.253340 140659525949248 model_lib_v2.py:1018] 	+ DetectionBoxes_Precision/mAP (large): 0.758546
# INFO:tensorflow:	+ DetectionBoxes_Recall/AR@1: 0.724000
# I0402 01:40:52.254740 140659525949248 model_lib_v2.py:1018] 	+ DetectionBoxes_Recall/AR@1: 0.724000
# INFO:tensorflow:	+ DetectionBoxes_Recall/AR@10: 0.727000
# I0402 01:40:52.256180 140659525949248 model_lib_v2.py:1018] 	+ DetectionBoxes_Recall/AR@10: 0.727000
# INFO:tensorflow:	+ DetectionBoxes_Recall/AR@100: 0.729000
# I0402 01:40:52.257516 140659525949248 model_lib_v2.py:1018] 	+ DetectionBoxes_Recall/AR@100: 0.729000
# INFO:tensorflow:	+ DetectionBoxes_Recall/AR@100 (small): -1.000000
# I0402 01:40:52.258663 140659525949248 model_lib_v2.py:1018] 	+ DetectionBoxes_Recall/AR@100 (small): -1.000000
# INFO:tensorflow:	+ DetectionBoxes_Recall/AR@100 (medium): 0.717978
# I0402 01:40:52.260081 140659525949248 model_lib_v2.py:1018] 	+ DetectionBoxes_Recall/AR@100 (medium): 0.717978
# INFO:tensorflow:	+ DetectionBoxes_Recall/AR@100 (large): 0.818182
# I0402 01:40:52.261609 140659525949248 model_lib_v2.py:1018] 	+ DetectionBoxes_Recall/AR@100 (large): 0.818182
# INFO:tensorflow:	+ Loss/localization_loss: 0.115651
# I0402 01:40:52.262766 140659525949248 model_lib_v2.py:1018] 	+ Loss/localization_loss: 0.115651
# INFO:tensorflow:	+ Loss/classification_loss: 0.262404
# I0402 01:40:52.263824 140659525949248 model_lib_v2.py:1018] 	+ Loss/classification_loss: 0.262404
# INFO:tensorflow:	+ Loss/regularization_loss: 0.089528
# I0402 01:40:52.264877 140659525949248 model_lib_v2.py:1018] 	+ Loss/regularization_loss: 0.089528
# INFO:tensorflow:	+ Loss/total_loss: 0.467583
# I0402 01:40:52.265923 140659525949248 model_lib_v2.py:1018] 	+ Loss/total_loss: 0.467583
# INFO:tensorflow:Waiting for new checkpoint at Tensorflow/workspace/models/my_ssd_mobnet
# I0402 01:45:10.350010 140659525949248 checkpoint_utils.py:168] Waiting for new checkpoint at Tensorflow/workspace/models/my_ssd_mobnet
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.9/dist-packages/absl/app.py", line 308, in run
#     _run_main(main, args)
#   File "/usr/local/lib/python3.9/dist-packages/absl/app.py", line 254, in _run_main
#     sys.exit(main(argv))
#   File "/content/Tensorflow/models/research/object_detection/model_main_tf2.py", line 81, in main
#     model_lib_v2.eval_continuously(
#   File "/usr/local/lib/python3.9/dist-packages/object_detection/model_lib_v2.py", line 1135, in eval_continuously
#     for latest_checkpoint in tf.train.checkpoints_iterator(
#   File "/usr/local/lib/python3.9/dist-packages/tensorflow/python/training/checkpoint_utils.py", line 226, in checkpoints_iterator
#     new_checkpoint_path = wait_for_new_checkpoint(
#   File "/usr/local/lib/python3.9/dist-packages/tensorflow/python/training/checkpoint_utils.py", line 175, in wait_for_new_checkpoint
#     time.sleep(seconds_to_sleep)
# KeyboardInterrupt
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/content/Tensorflow/models/research/object_detection/model_main_tf2.py", line 114, in <module>
#     tf.compat.v1.app.run()
#   File "/usr/local/lib/python3.9/dist-packages/tensorflow/python/platform/app.py", line 36, in run
#     _run(main=main, argv=argv, flags_parser=_parse_flags_tolerate_undef)
#   File "/usr/local/lib/python3.9/dist-packages/absl/app.py", line 316, in run
#     if isinstance(exc, SystemExit) and not exc.code:
# KeyboardInterrupt
# ^C

# %% [markdown]
# # 8. Load Train Model From Checkpoint

# %%
import os
import tensorflow as tf
from object_detection.utils import label_map_util
from object_detection.utils import visualization_utils as viz_utils
from object_detection.builders import model_builder
from object_detection.utils import config_util
# Out:
# /usr/local/lib/python3.9/dist-packages/tensorflow_addons/utils/ensure_tf_install.py:53: UserWarning: Tensorflow Addons supports using Python ops for all Tensorflow versions above or equal to 2.9.0 and strictly below 2.12.0 (nightly versions are not supported).
#  The versions of TensorFlow you are currently using is 2.12.0 and is not supported.
# Some things might work, some things might not.
# If you were to encounter a bug, do not file an issue.
# If you want to make sure you're using a tested and supported configuration, either change the TensorFlow version or the TensorFlow Addons's version.
# You can find the compatibility matrix in TensorFlow Addon's readme:
# https://github.com/tensorflow/addons
#   warnings.warn(

# %%
# Load pipeline config and build a detection model
configs = config_util.get_configs_from_pipeline_file(files['PIPELINE_CONFIG'])
detection_model = model_builder.build(model_config=configs['model'], is_training=False)

# Restore checkpoint
ckpt = tf.compat.v2.train.Checkpoint(model=detection_model)
ckpt.restore(os.path.join(paths['CHECKPOINT_PATH'], 'ckpt-52')).expect_partial()

@tf.function
def detect_fn(image):
    image, shapes = detection_model.preprocess(image)
    prediction_dict = detection_model.predict(image, shapes)
    detections = detection_model.postprocess(prediction_dict, shapes)
    return detections

# %% [markdown]
# # 9. Detect from an Image

# %%
import cv2 
import numpy as np
from matplotlib import pyplot as plt
# %matplotlib inline

# %%
category_index = label_map_util.create_category_index_from_labelmap(files['LABELMAP'])

# %%
IMAGE_PATH = os.path.join(paths['IMAGE_PATH'], 'test', 'livelong.02533422-940e-11eb-9dbd-5cf3709bbcc6.jpg')

# %%
img = cv2.imread('/content/Tensorflow/workspace/images/test/803.jpg')
image_np = np.array(img)

input_tensor = tf.convert_to_tensor(np.expand_dims(image_np, 0), dtype=tf.float32)
detections = detect_fn(input_tensor)

num_detections = int(detections.pop('num_detections'))
detections = {key: value[0, :num_detections].numpy()
              for key, value in detections.items()}
detections['num_detections'] = num_detections

# detection_classes should be ints.
detections['detection_classes'] = detections['detection_classes'].astype(np.int64)

label_id_offset = 1
image_np_with_detections = image_np.copy()

viz_utils.visualize_boxes_and_labels_on_image_array(
            image_np_with_detections,
            detections['detection_boxes'],
            detections['detection_classes']+label_id_offset,
            detections['detection_scores'],
            category_index,
            use_normalized_coordinates=True,
            max_boxes_to_draw=3,
            min_score_thresh=.3,
            agnostic_mode=False)

plt.imshow(cv2.cvtColor(image_np_with_detections, cv2.COLOR_BGR2RGB))
plt.show()

# %% [markdown]
# # 13. Zip and Export Models

# %%
# !tar -czf models.tar.gz {paths['CHECKPOINT_PATH']}

# %%
shutil.copy('/content/models.tar.gz', '/content/drive/MyDrive/License Plate')
# Out:
# '/content/drive/MyDrive/License Plate/models.tar.gz'

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive
